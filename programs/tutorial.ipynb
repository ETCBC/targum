# %%
# %load_ext autoreload
# %autoreload 2

# %%
from tf.app import use

ORG = "etcbc"
REPO = "targum"
A = use(f"{ORG}/{REPO}:clone", checkout="clone", version="0.0.1-alpha", hoist=globals())
# Out:
# **Locating corpus resources ...**
# <b title="local github">app:</b> <span title="repo clone offline under /Users/samuelswire/github">~/github/etcbc/targum/app</span>
# <b title="local github">data:</b> <span title="repo clone offline under /Users/samuelswire/github">~/github/etcbc/targum/tf/0.0.1-alpha</span>
#             <b>TF:</b> <a target="_blank" href="https://annotation.github.io/text-fabric/tf/cheatsheet.html" title="text-fabric api">TF API 13.1.0</a>, <a target="_blank" href="https://github.com/etcbc/targum/blob/main/app" title="etcbc/targum app">etcbc/targum/app  v3</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/tf/about/searchusage.html" title="Search Templates Introduction and Reference">Search Reference</a><br>
#             <b>Data:</b> <a target="_blank" href="https://github.com/etcbc/targum/blob/main/docs/about.md" title="provenance of etcbc - targum/tf">etcbc - targum 0.0.1-alpha</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/tf/writing/" title="How TF features represent text">Character table</a>, <a target="_blank" href="https://github.com/etcbc/targum/blob/main/docs/transcription.md" title="etcbc - targum feature documentation">Feature docs</a><br>
#             <details class="nodeinfo"><summary><b>Node types</b></summary>
# <table class="nodeinfo">
#     <tr>
#         <th>Name</th>
#         <th># of nodes</th>
#         <th># slots / node</th>
#         <th>% coverage</th>
#     </tr>
#
# <tr>
#     <th>text</th>
#     <td>68</td>
#     <td>7279.79</td>
#     <td><b>100</b></td>
# </tr>
#
# <tr>
#     <th>book</th>
#     <td>81</td>
#     <td>6111.43</td>
#     <td><b>100</b></td>
# </tr>
#
# <tr>
#     <th>chapter</th>
#     <td>1026</td>
#     <td>482.48</td>
#     <td><b>100</b></td>
# </tr>
#
# <tr>
#     <th>verse</th>
#     <td>20253</td>
#     <td>24.44</td>
#     <td><b>100</b></td>
# </tr>
#
# <tr>
#     <th>segment</th>
#     <td>51151</td>
#     <td>9.68</td>
#     <td><b>100</b></td>
# </tr>
#
# <tr>
#     <th><i>word</i></th>
#     <td>495026</td>
#     <td>1.00</td>
#     <td><b>100</b></td>
# </tr>
# </table></details>
#             <b>Sets:</b> no custom sets<br>
#             <b>Features:</b><br>
# <details><summary><b>etcbc - targum/tf</b></summary>
#     <div class="fcorpus">
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/etcbc/targum/blob/main/docs/transcription.md" title="~/github/etcbc/targum/tf/0.0.1-alpha/book.tf">book</a>
# </div>
# <div class="fmono">str</div>
#
# <span> Name of Biblical book</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/etcbc/targum/blob/main/docs/transcription.md" title="~/github/etcbc/targum/tf/0.0.1-alpha/chapter.tf">chapter</a>
# </div>
# <div class="fmono">str</div>
#
# <span> Chapter of the book</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/etcbc/targum/blob/main/docs/transcription.md" title="~/github/etcbc/targum/tf/0.0.1-alpha/cons.tf">cons</a>
# </div>
# <div class="fmono">str</div>
#
# <span> Auto-extracted XML attribute cons</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/etcbc/targum/blob/main/docs/transcription.md" title="~/github/etcbc/targum/tf/0.0.1-alpha/cons_utf8.tf">cons_utf8</a>
# </div>
# <div class="fmono">str</div>
#
# <span> Auto-extracted XML attribute cons_utf8</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/etcbc/targum/blob/main/docs/transcription.md" title="~/github/etcbc/targum/tf/0.0.1-alpha/definition.tf">definition</a>
# </div>
# <div class="fmono">str</div>
#
# <span> Extended translation or dictionary definition</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/etcbc/targum/blob/main/docs/transcription.md" title="~/github/etcbc/targum/tf/0.0.1-alpha/description.tf">description</a>
# </div>
# <div class="fmono">str</div>
#
# <span> Description of a text, view, monad, lemma, etc.</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/etcbc/targum/blob/main/docs/transcription.md" title="~/github/etcbc/targum/tf/0.0.1-alpha/end_idx.tf">end_idx</a>
# </div>
# <div class="fmono">int</div>
#
# <span> Ending index of the segment within the line</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/etcbc/targum/blob/main/docs/transcription.md" title="~/github/etcbc/targum/tf/0.0.1-alpha/gloss.tf">gloss</a>
# </div>
# <div class="fmono">str</div>
#
# <span> English gloss</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/etcbc/targum/blob/main/docs/transcription.md" title="~/github/etcbc/targum/tf/0.0.1-alpha/gn.tf">gn</a>
# </div>
# <div class="fmono">str</div>
#
# <span> Gender (nominal only, partial)</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/etcbc/targum/blob/main/docs/transcription.md" title="~/github/etcbc/targum/tf/0.0.1-alpha/group_id.tf">group_id</a>
# </div>
# <div class="fmono">str</div>
#
# <span> Auto-extracted XML attribute group_id</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/etcbc/targum/blob/main/docs/transcription.md" title="~/github/etcbc/targum/tf/0.0.1-alpha/id.tf">id</a>
# </div>
# <div class="fmono">int</div>
#
# <span> xml id, associated to primary key in other data stores (SQL)</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/etcbc/targum/blob/main/docs/transcription.md" title="~/github/etcbc/targum/tf/0.0.1-alpha/lex.tf">lex</a>
# </div>
# <div class="fmono">str</div>
#
# <span> Lexeme in ETCBC transcription</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/etcbc/targum/blob/main/docs/transcription.md" title="~/github/etcbc/targum/tf/0.0.1-alpha/line.tf">line</a>
# </div>
# <div class="fmono">str</div>
#
# <span> Auto-extracted XML attribute line</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/etcbc/targum/blob/main/docs/transcription.md" title="~/github/etcbc/targum/tf/0.0.1-alpha/line_utf8.tf">line_utf8</a>
# </div>
# <div class="fmono">str</div>
#
# <span> Auto-extracted XML attribute line_utf8</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/etcbc/targum/blob/main/docs/transcription.md" title="~/github/etcbc/targum/tf/0.0.1-alpha/nu.tf">nu</a>
# </div>
# <div class="fmono">str</div>
#
# <span> Number (nominal only, partial)</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/etcbc/targum/blob/main/docs/transcription.md" title="~/github/etcbc/targum/tf/0.0.1-alpha/otype.tf">otype</a>
# </div>
# <div class="fmono">str</div>
#
# <span> </span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/etcbc/targum/blob/main/docs/transcription.md" title="~/github/etcbc/targum/tf/0.0.1-alpha/rank.tf">rank</a>
# </div>
# <div class="fmono">int</div>
#
# <span> Sequential or hierarchical rank of the segment</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/etcbc/targum/blob/main/docs/transcription.md" title="~/github/etcbc/targum/tf/0.0.1-alpha/root.tf">root</a>
# </div>
# <div class="fmono">str</div>
#
# <span> Root, typically of a verb</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/etcbc/targum/blob/main/docs/transcription.md" title="~/github/etcbc/targum/tf/0.0.1-alpha/segment.tf">segment</a>
# </div>
# <div class="fmono">str</div>
#
# <span> Grouping of monads/monad groups based on position within discrete editorial or emendation blocks (e.g., variants)</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/etcbc/targum/blob/main/docs/transcription.md" title="~/github/etcbc/targum/tf/0.0.1-alpha/segment_utf8.tf">segment_utf8</a>
# </div>
# <div class="fmono">str</div>
#
# <span> Auto-extracted XML attribute segment_utf8</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/et
# <style>tr.tf.ltr, td.tf.ltr, th.tf.ltr { text-align: left ! important;}
# tr.tf.rtl, td.tf.rtl, th.tf.rtl { text-align: right ! important;}
# @font-face {
#   font-family: "Gentium Plus";
#   src: local('Gentium Plus'), local('GentiumPlus'),
#     url('/browser/static/fonts/GentiumPlus-R.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/GentiumPlus-R.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "Ezra SIL";
#   src: local('Ezra SIL'), local('EzraSIL'),
#     url('/browser/static/fonts/SILEOT.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/SILEOT.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "SBL Hebrew";
#   src: local('SBL Hebrew'), local('SBLHebrew'),
#     url('/browser/static/fonts/SBL_Hbrw.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/SBL_Hbrw.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "Estrangelo Edessa";
#   src: local('Estrangelo Edessa'), local('EstrangeloEdessa');
#     url('/browser/static/fonts/SyrCOMEdessa.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/SyrCOMEdessa.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: AmiriQuran;
#   font-style: normal;
#   font-weight: 400;
#   src: local('Amiri Quran'), local('AmiriQuran'),
#     url('/browser/static/fonts/AmiriQuran.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/AmiriQuran.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: AmiriQuranColored;
#   font-style: normal;
#   font-weight: 400;
#   src: local('Amiri Quran Colored'), local('AmiriQuranColored'),
#     url('/browser/static/fonts/AmiriQuranColored.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/AmiriQuranColored.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "Santakku";
#   src: local('Santakku'),
#     url('/browser/static/fonts/Santakku.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/Santakku.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "SantakkuM";
#   src: local('SantakkuM'),
#     url('/browser/static/fonts/SantakkuM.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/SantakkuM.woff?raw=true') format('woff');
# }
#
# /* bypassing some classical notebook settings */
# div#notebook {
#   line-height: unset;
# }
# /* neutral text */
# .txtn,.txtn a:visited,.txtn a:link {
#     font-family: sans-serif;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* transcription text */
# .txtt,.txtt a:visited,.txtt a:link {
#     font-family: monospace;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* source text */
# .txto,.txto a:visited,.txto a:link {
#     font-family: serif;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* phonetic text */
# .txtp,.txtp a:visited,.txtp a:link {
#     font-family: Gentium, sans-serif;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* original script text */
# .txtu,.txtu a:visited,.txtu a:link {
#     font-family: Gentium, sans-serif;
#     font-size: medium;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* hebrew */
# .txtu.hbo,.lex.hbo {
#     font-family: "Ezra SIL", "SBL Hebrew", sans-serif;
#     font-size: large;
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# /* syriac */
# .txtu.syc,.lex.syc {
#     font-family: "Estrangelo Edessa", sans-serif;
#     font-size: medium;
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# /* neo aramaic */
# .txtu.cld,.lex.cld {
#     font-family: "CharisSIL-R", sans-serif;
#     font-size: medium;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# /* standard arabic */
# .txtu.ara,.lex.ara {
#     font-family: "AmiriQuran", sans-serif;
#     font-size: large;
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# /* cuneiform */
# .txtu.akk,.lex.akk {
#     font-family: Santakku, sans-serif;
#     font-size: large;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# .txtu.uga,.lex.uga {
#     font-family: sans-serif;
#     /*font-family: Noto Sans Ugaritic, sans-serif;*/
#     font-size: large;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# /* greek */
# .txtu.grc,.lex.grc a:link {
#     font-family: Gentium, sans-serif;
#     font-size: medium;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# a:hover {
#     text-decoration: underline | important;
#     color: #0000ff | important;
# }
# .ltr {
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# .rtl {
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# .ubd {
#     unicode-bidi: embed;
# }
# .col {
#    display: inline-block;
# }
# .features {
#     font-family: monospace;
#     font-size: medium;
#     font-weight: bold;
#     color: var(--features);
#     display: flex;
#     flex-flow: column nowrap;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     padding: 2px;
#     margin: 2px;
#     direction: ltr;
#     unicode-bidi: embed;
#     border: var(--meta-width) solid var(--meta-color);
#     border-radius: var(--meta-width);
# }
# .features div,.features span {
#     padding: 0;
#     margin: -2px 0;
# }
# .features .f {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: normal;
#     color: #5555bb;
# }
# .features .xft {
#   color: #000000;
#   background-color: #eeeeee;
#   font-size: medium;
#   margin: 2px 0px;
# }
# .features .xft .f {
#   color: #000000;
#   background-color: #eeeeee;
#   font-size: small;
#   font-weight: normal;
# }
# .tfsechead {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: bold;
#     color: var(--tfsechead);
#     unicode-bidi: embed;
#     text-align: start;
# }
# .structure {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: bold;
#     color: var(--structure);
#     unicode-bidi: embed;
#     text-align: start;
# }
# .comments {
#     display: flex;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     flex-flow: column nowrap;
# }
# .nd, a:link.nd {
#     font-family: sans-serif;
#     font-size: small;
#     color: var(--node);
#     vertical-align: super;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# .nde, a:link.nde {
#     font-family: sans-serif;
#     font-size: small;
#     color: var(--node);
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# .etf {
#     font-size: normal;
#     border-radius: 0.2rem;
#     border: 1pt solid white;
#     padding: 0 0.2rem ! important;
#     margin: 0 0.2rem ! important;
# }
# .etfx {
#     font-size: x-large;
# }
# .lex {
#   color: var(--lex-color);;
# }
# #colormapplus, #colormapmin, .ecolormapmin {
#   font-weight: bold;
#   border-radius: 0.1rem;
#   background-color: #eeeeff;
#   padding: 0 1rem;
#   margin: 0 1rem;
# }
# .clr {
#   font-style: italic;
#   font-size: small;
# }
# .clmap,.eclmap {
#   padding: 0;
# }
# .children,.children.ltr {
#     display: flex;
#     border: 0;
#     background-color: #ffffff;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
# }
# .children.stretch {
#     align-items: stretch;
# }
# .children.hor {
#     flex-flow: row nowrap;
# }
# .children.hor.wrap {
#     flex-flow: row wrap;
# }
# .children.ver {
#     flex-flow: column nowrap;
# }
# .children.ver.wrap {
#     flex-flow: column wrap;
# }
# .contnr {
#     width: fit-content;
#     display: flex;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     flex-flow: column nowrap;
#     background: #ffffff none repeat scroll 0 0;
#     padding:  10px 2px 2px 2px;
#     margin: 16px 2px 2px 2px;
#     border-style: solid;
#     font-size: small;
# }
# .c
# <script>
# globalThis.copyChar = (el, c) => {
#     for (const el of document.getElementsByClassName('ccon')) {
#         el.className = 'ccoff'
#     }
#     el.className = 'ccon'
#     navigator.clipboard.writeText(String.fromCharCode(c))
# }
# </script>
# <div><b>TF API:</b> names <a target="_blank" href="https://annotation.github.io/text-fabric/tf/cheatsheet.html" title="doc">N F E L T S C TF Fs Fall Es Eall Cs Call</a> directly usable</div><hr>

# %%
A.indent(reset=True)
A.info("counting objects ...")

for otype in F.otype.all:
    i = 0

    A.indent(level=1, reset=True)

    for n in F.otype.s(otype):
        i += 1

    A.info("{:>7} {}s".format(i, otype))

A.indent(level=0)
A.info("Done")
# Out:
#   0.00s counting objects ...
#    |     0.00s      68 texts
#    |     0.00s      81 books
#    |     0.00s    1026 chapters
#    |     0.00s   20253 verses
#    |     0.01s   51151 segments
#    |     0.08s  495026 words
#   0.10s Done

# %%
F.sp.freqList()
# Out:
# (('subs', 131418),
#  ('prep', 106406),
#  ('conj', 79647),
#  ('verb', 78200),
#  ('pron', 13777),
#  ('advb', 12957),
#  ('adjv', 12405),
#  ('unknown', 5275),
#  ('intj', 1711))

# %%
for n in [1, L.u(1, otype="verse")[0]]:
    A.indent(level=0)
    A.info("Node {}".format(n), tm=False)
    A.indent(level=1)
    A.info("UP", tm=False)
    A.indent(level=2)
    A.info("\n".join(["{:<15} {}".format(u, F.otype.v(u)) for u in L.u(n)]), tm=False)
    A.indent(level=1)
    A.info("DOWN", tm=False)
    A.indent(level=2)
    A.info("\n".join(["{:<15} {}".format(u, F.otype.v(u)) for u in L.d(n)]), tm=False)
A.indent(level=0)
A.info("Done", tm=False)
# Out:
# Node 1
#    |   UP
#    |      |   496134          segment
#    |      |   547353          verse
#    |      |   495108          chapter
#    |      |   495027          book
#    |      |   547285          text
#    |   DOWN
#    |      |   .
# Node 547353
#    |   UP
#    |      |   495108          chapter
#    |      |   495027          book
#    |      |   547285          text
#    |   DOWN
#    |      |   496134          segment
#    |      |   1               word
#    |      |   2               word
#    |      |   3               word
#    |      |   4               word
#    |      |   5               word
#    |      |   6               word
#    |      |   7               word
#    |      |   8               word
#    |      |   9               word
#    |      |   10              word
#    |      |   11              word
#    |      |   12              word
#    |      |   13              word
#    |      |   14              word
#    |      |   15              word
#    |      |   16              word
#    |      |   17              word
#    |      |   18              word
#    |      |   19              word
#    |      |   20              word
#    |      |   21              word
#    |      |   22              word
#    |      |   23              word
#    |      |   24              word
#    |      |   25              word
#    |      |   26              word
#    |      |   27              word
#    |      |   28              word
#    |      |   29              word
#    |      |   30              word
#    |      |   31              word
#    |      |   32              word
#    |      |   33              word
#    |      |   34              word
#    |      |   35              word
#    |      |   36              word
#    |      |   37              word
#    |      |   38              word
#    |      |   39              word
#    |      |   40              word
#    |      |   41              word
#    |      |   42              word
#    |      |   43              word
#    |      |   44              word
#    |      |   45              word
#    |      |   46              word
#    |      |   47              word
#    |      |   48              word
#    |      |   49              word
#    |      |   50              word
#    |      |   51              word
#    |      |   52              word
#    |      |   53              word
#    |      |   54              word
#    |      |   55              word
#    |      |   56              word
#    |      |   57              word
#    |      |   58              word
#    |      |   59              word
#    |      |   60              word
#    |      |   61              word
#    |      |   62              word
#    |      |   63              word
#    |      |   64              word
#    |      |   65              word
#    |      |   66              word
#    |      |   67              word
#    |      |   68              word
#    |      |   69              word
#    |      |   70              word
#    |      |   71              word
#    |      |   72              word
#    |      |   73              word
#    |      |   74              word
#    |      |   75              word
#    |      |   76              word
#    |      |   77              word
#    |      |   78              word
#    |      |   496135          segment
#    |      |   79              word
#    |      |   80              word
#    |      |   496136          segment
#    |      |   81              word
#    |      |   82              word
#    |      |   83              word
#    |      |   84              word
#    |      |   85              word
#    |      |   86              word
#    |      |   87              word
#    |      |   88              word
#    |      |   89              word
#    |      |   90              word
#    |      |   91              word
#    |      |   92              word
#    |      |   93              word
#    |      |   94              word
#    |      |   95              word
#    |      |   96              word
#    |      |   97              word
#    |      |   98              word
#    |      |   99              word
#    |      |   100             word
#    |      |   101             word
#    |      |   102             word
#    |      |   103             word
#    |      |   104             word
#    |      |   105             word
#    |      |   106             word
#    |      |   107             word
#    |      |   108             word
#    |      |   109             word
#    |      |   110             word
#    |      |   111             word
#    |      |   112             word
#    |      |   113             word
#    |      |   114             word
#    |      |   115             word
#    |      |   116             word
#    |      |   117             word
#    |      |   118             word
#    |      |   119             word
#    |      |   120             word
#    |      |   121             word
#    |      |   122             word
#    |      |   123             word
#    |      |   124             word
#    |      |   125             word
#    |      |   126             word
#    |      |   127             word
#    |      |   128             word
#    |      |   129             word
#    |      |   130             word
#    |      |   131             word
#    |      |   132             word
#    |      |   133             word
#    |      |   134             word
#    |      |   135             word
#    |      |   136             word
#    |      |   137             word
#    |      |   138             word
#    |      |   139             word
#    |      |   140             word
#    |      |   141             word
#    |      |   142             word
#    |      |   143             word
#    |      |   144             word
#    |      |   145             word
#    |      |   146             word
#    |      |   147             word
#    |      |   148             word
#    |      |   149             word
#    |      |   150             word
#    |      |   151             word
#    |      |   152             word
#    |      |   153             word
#    |      |   154             word
#    |      |   155             word
#    |      |   156             word
#    |      |   157             word
#    |      |   158             word
#    |      |   159             word
#    |      |   160             word
#    |      |   161             word
#    |      |   162             word
#    |      |   163             word
#    |      |   164             word
#    |      |   165             word
# Done

# %%
exampleNodes = [
    1,
    F.otype.s("segment")[0],
    F.otype.s("verse")[0],
    F.otype.s("chapter")[0],
]

for n in exampleNodes:
    print(f"This is {F.otype.v(n)} {n}:")
    print(T.text(n))
    print("")
# Out:
# This is word 1:
# איליין
#
# This is segment 496134:
# איליין פיתגמיא די מליל משׁה עם כל ישׁראל בעבר יורדנא עני משׁה ואמר להון הלא במדבר בטורא דסיני איתיהיבת לכון אוריתא ובמישׁרא דמואב איתפרשׁת לכון כמא נסין וגבורן עבד לכון מימרא דייי כד הויתון קיימין עלגיףגיף ימא דסוף איתבזע ימא מןקומיכון ואתעבד תרתיעשׁרי איסטרטין מן אסטרא חד לכל שׁבט ארגזתון קומוי על ימא וסרבתון על ימא דסוף עלעיסקעלעיסק יליליא
#
# This is verse 547353:
# איליין פיתגמיא די מליל משׁה עם כל ישׁראל בעבר יורדנא עני משׁה ואמר להון הלא במדבר בטורא דסיני איתיהיבת לכון אוריתא ובמישׁרא דמואב איתפרשׁת לכון כמא נסין וגבורן עבד לכון מימרא דייי כד הויתון קיימין עלגיףגיף ימא דסוף איתבזע ימא מןקומיכון ואתעבד תרתיעשׁרי איסטרטין מן אסטרא חד לכל שׁבט ארגזתון קומוי על ימא וסרבתון על ימא דסוף עלעיסקעלעיסק יליליא דאשׁתלחתון מן מדברא דפארן גזר ליכון דלא תעלון לארעא דישׁראל ובגין מילתא דאמרתון דנפשׁן מעיקן בלחם הדין דכליה קליל וגרי בכון חיון ובחצרות די נפלו פגריכון עלידיידי ביסרא ובגין עגלא דעבדתון אמר במימריה למשׁציא יתכון אילולי דאידכר לכון קיימא די קיים עם אבהתכון עם אברהם עם יצחק ועם יעקב ומשׁכן זימנא די עבדתון לשׁמיה וארון קיימא די עליתון בגויה וחפיתון יתיה בדהבא סנינא
#
# This is chapter 495108:
# איליין פיתגמיא די מליל משׁה עם כל ישׁראל בעבר יורדנא עני משׁה ואמר להון הלא במדבר בטורא דסיני איתיהיבת לכון אוריתא ובמישׁרא דמואב איתפרשׁת לכון כמא נסין וגבורן עבד לכון מימרא דייי כד הויתון קיימין עלגיףגיף ימא דסוף איתבזע ימא מןקומיכון ואתעבד תרתיעשׁרי איסטרטין מן אסטרא חד לכל שׁבט ארגזתון קומוי על ימא וסרבתון על ימא דסוף עלעיסקעלעיסק יליליא דאשׁתלחתון מן מדברא דפארן גזר ליכון דלא תעלון לארעא דישׁראל ובגין מילתא דאמרתון דנפשׁן מעיקן בלחם הדין דכליה קליל וגרי בכון חיון ובחצרות די נפלו פגריכון עלידיידי ביסרא ובגין עגלא דעבדתון אמר במימריה למשׁציא יתכון אילולי דאידכר לכון קיימא די קיים עם אבהתכון עם אברהם עם יצחק ועם יעקב ומשׁכן זימנא די עבדתון לשׁמיה וארון קיימא די עליתון בגויה וחפיתון יתיה בדהבא סנינא מהלך חדעשׁר יומין מן טורא דחורב אורח טורא דגבלא עד רקםרדגיעא על דחטיתון וארגזתון קומוי אתעכבתון והליכתון יתהון לארבעין שׁנין

# %%
for fmt in sorted(T.formats):
    print("{}:\n\t{}".format(fmt, T.text(range(1, 12), fmt=fmt)))
# Out:
# lex-orig-full:
# 	אלין פתגם די מלל  עם כל  בעבר ירדן
# text-cons:
# 	איליין פיתגמיא די מליל משׁה עם כל ישׁראל בעבר יורדנא
# text-orig-full:
# 	איליין פיתגמיא די מליל משׁה עם כל ישׁראל בעבר יורדנא
# text-trans-cons:
# 	>JLJJn PJTGMJ> DJ MLJL MCH <m KL JCR>L B<BR JWRDN>
# text-trans-full:
# 	>JLJJn PJTGMJ> DJ MLJL MCH <m KL JCR>L B<BR JWRDN>

# %%
A.indent(reset=True)
A.info("counting objects ...")

for otype in F.otype.all:
    i = 0
    A.indent(level=1, reset=True)

    for n in F.otype.s(otype):
        i += 1

    A.info("{:>7} {}s".format(i, otype))

A.indent(level=0)
A.info("Done")

wordShow = (1, 25000, 40000, 8000)
for word in wordShow:
    A.pretty(word, withNodes=True)
# Out:
#   0.00s counting objects ...
#    |     0.00s      68 texts
#    |     0.00s      81 books
#    |     0.00s    1026 chapters
#    |     0.00s   20253 verses
#    |     0.01s   51151 segments
#    |     0.08s  495026 words
#   0.09s Done
# <div class="tfsechead "><span class="ltr"><a target="_blank" href="https://public.etcbc.org/targum/fragment_targum_p/Deuteronomy/1&amp;version=0.0.1-alpha" title="Show this on the website" sec="fragment_targum_p@Deuteronomy:1">fragment_targum_p@Deuteronomy:1</a></span></div><div class=" children pr-mode"><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="nd">1 </span> <span class="txtu">איליין</span></div></div></div>
# <div class="tfsechead "><span class="ltr"><a target="_blank" href="https://public.etcbc.org/targum/pseudo_jonathan/Genesis/14&amp;version=0.0.1-alpha" title="Show this on the website" sec="pseudo_jonathan@Genesis:14">pseudo_jonathan@Genesis:14</a></span></div><div class=" children pr-mode"><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="nd">25000 </span> <span class="txtu">אברם </span></div></div></div>
# <div class="tfsechead "><span class="ltr"><a target="_blank" href="https://public.etcbc.org/targum/pseudo_jonathan/Genesis/32&amp;version=0.0.1-alpha" title="Show this on the website" sec="pseudo_jonathan@Genesis:32">pseudo_jonathan@Genesis:32</a></span></div><div class=" children pr-mode"><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="nd">40000 </span> <span class="txtu">מלאכא</span></div></div></div>
# <div class="tfsechead "><span class="ltr"><a target="_blank" href="https://public.etcbc.org/targum/fragment_targum_v/Genesis/43&amp;version=0.0.1-alpha" title="Show this on the website" sec="fragment_targum_v@Genesis:43">fragment_targum_v@Genesis:43</a></span></div><div class=" children pr-mode"><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="nd">8000 </span> <span class="txtu">מתכלה</span></div></div></div>

# %%
F.otype.s("text")
# Out:
# (868731,
#  868732,
#  868733,
#  868734,
#  868735,
#  868736,
#  868737,
#  868738,
#  868739,
#  868740,
#  868741,
#  868742,
#  868743,
#  868744,
#  868745,
#  868746,
#  868747,
#  868748,
#  868749,
#  868750,
#  868751,
#  868752,
#  868753,
#  868754,
#  868755,
#  868756,
#  868757,
#  868758,
#  868759)

# %%
for x in (
    ("section of first word", T.sectionFromNode(1)),
    ("node of Genesis 1:1", T.nodeFromSection(("Genesis", 1, 1))),
    ("node of book Genesis", T.nodeFromSection(("Genesis",))),
    ("node of chapter Genesis 1", T.nodeFromSection(("Genesis", 1))),
    ("section of book node", T.sectionFromNode(109641)),
    ("idem, now last word", T.sectionFromNode(109641, lastSlot=True)),
    ("section of chapter node", T.sectionFromNode(109668)),
    ("idem, now last word", T.sectionFromNode(109668, lastSlot=True)),
):
    print("{:<30} {}".format(*x))
# Out:
# section of first word          ('fragment_targum_p', 'Deuteronomy', '1')
# node of Genesis 1:1            None
# node of book Genesis           None
# node of chapter Genesis 1      None
# section of book node           ('neofiti_base', 'Exodus', '19')
# idem, now last word            ('neofiti_base', 'Exodus', '19')
# section of chapter node        ('neofiti_base', 'Exodus', '19')
# idem, now last word            ('neofiti_base', 'Exodus', '19')

# %%
query = """
text text=neofiti_base
    book book=Genesis
      chapter chapter=1
        word sp=subs
"""
results = A.search(query)
A.table(results, end=20, skipCols="1 2")
# Out:
#   0.27s 264 results
# <table><tr class="tf ltr"><th class="tf ltr">n</th><th class="tf ltr">p</th><th class="tf ltr">text</th><th class="tf">book</th><th class="tf">chapter</th><th class="tf">word</th></tr>
# <tr class="tf ltr"><td class="tf ltr">1</td><td class="tf ltr"><span class="tfsechead ltr"><span class="ltr"><a target="_blank" href="https://public.etcbc.org/targum/neofiti_base/Genesis/1&amp;version=0.0.1-alpha" title="Show this on the website" sec="neofiti_base@Genesis:1">neofiti_base@Genesis:1</a></span></span></td><td class="tf ltr"></td><td class="tf ltr"></td><td class="tf ltr"><span class=" ubd pl-mode"></span></td><td class="tf ltr"><span class=" ubd pl-mode"><span class="plain   hl" ><span class="txtu">חכמה</span></span></span></td></tr>
# <tr class="tf ltr"><td class="tf ltr">2</td><td class="tf ltr"><span class="tfsechead ltr"><span class="ltr"><a target="_blank" href="https://public.etcbc.org/targum/neofiti_base/Genesis/1&amp;version=0.0.1-alpha" title="Show this on the website" sec="neofiti_base@Genesis:1">neofiti_base@Genesis:1</a></span></span></td><td class="tf ltr"></td><td class="tf ltr"></td><td class="tf ltr"><span class=" ubd pl-mode"></span></td><td class="tf ltr"><span class=" ubd pl-mode"><span class="plain   hl" ><span class="txtu">ייי</span></span></span></td></tr>
# <tr class="tf ltr"><td class="tf ltr">3</td><td class="tf ltr"><span class="tfsechead ltr"><span class="ltr"><a target="_blank" href="https://public.etcbc.org/targum/neofiti_base/Genesis/1&amp;version=0.0.1-alpha" title="Show this on the website" sec="neofiti_base@Genesis:1">neofiti_base@Genesis:1</a></span></span></td><td class="tf ltr"></td><td class="tf ltr"></td><td class="tf ltr"><span class=" ubd pl-mode"></span></td><td class="tf ltr"><span class=" ubd pl-mode"><span class="plain   hl" ><span class="txtu">שׁמיא</span></span></span></td></tr>
# <tr class="tf ltr"><td class="tf ltr">4</td><td class="tf ltr"><span class="tfsechead ltr"><span class="ltr"><a target="_blank" href="https://public.etcbc.org/targum/neofiti_base/Genesis/1&amp;version=0.0.1-alpha" title="Show this on the website" sec="neofiti_base@Genesis:1">neofiti_base@Genesis:1</a></span></span></td><td class="tf ltr"></td><td class="tf ltr"></td><td class="tf ltr"><span class=" ubd pl-mode"></span></td><td class="tf ltr"><span class=" ubd pl-mode"><span class="plain   hl" ><span class="txtu">ארעא </span></span></span></td></tr>
# <tr class="tf ltr"><td class="tf ltr">5</td><td class="tf ltr"><span class="tfsechead ltr"><span class="ltr"><a target="_blank" href="https://public.etcbc.org/targum/neofiti_base/Genesis/1&amp;version=0.0.1-alpha" title="Show this on the website" sec="neofiti_base@Genesis:1">neofiti_base@Genesis:1</a></span></span></td><td class="tf ltr"></td><td class="tf ltr"></td><td class="tf ltr"><span class=" ubd pl-mode"></span></td><td class="tf ltr"><span class=" ubd pl-mode"><span class="plain   hl" ><span class="txtu">ארעא</span></span></span></td></tr>
# <tr class="tf ltr"><td class="tf ltr">6</td><td class="tf ltr"><span class="tfsechead ltr"><span class="ltr"><a target="_blank" href="https://public.etcbc.org/targum/neofiti_base/Genesis/1&amp;version=0.0.1-alpha" title="Show this on the website" sec="neofiti_base@Genesis:1">neofiti_base@Genesis:1</a></span></span></td><td class="tf ltr"></td><td class="tf ltr"></td><td class="tf ltr"><span class=" ubd pl-mode"></span></td><td class="tf ltr"><span class=" ubd pl-mode"><span class="plain   hl" ><span class="txtu">ברנשׁ</span></span></span></td></tr>
# <tr class="tf ltr"><td class="tf ltr">7</td><td class="tf ltr"><span class="tfsechead ltr"><span class="ltr"><a target="_blank" href="https://public.etcbc.org/targum/neofiti_base/Genesis/1&amp;version=0.0.1-alpha" title="Show this on the website" sec="neofiti_base@Genesis:1">neofiti_base@Genesis:1</a></span></span></td><td class="tf ltr"></td><td class="tf ltr"></td><td class="tf ltr"><span class=" ubd pl-mode"></span></td><td class="tf ltr"><span class=" ubd pl-mode"><span class="plain   hl" ><span class="txtu">בעיר</span></span></span></td></tr>
# <tr class="tf ltr"><td class="tf ltr">8</td><td class="tf ltr"><span class="tfsechead ltr"><span class="ltr"><a target="_blank" href="https://public.etcbc.org/targum/neofiti_base/Genesis/1&amp;version=0.0.1-alpha" title="Show this on the website" sec="neofiti_base@Genesis:1">neofiti_base@Genesis:1</a></span></span></td><td class="tf ltr"></td><td class="tf ltr"></td><td class="tf ltr"><span class=" ubd pl-mode"></span></td><td class="tf ltr"><span class=" ubd pl-mode"><span class="plain   hl" ><span class="txtu">כל</span></span></span></td></tr>
# <tr class="tf ltr"><td class="tf ltr">9</td><td class="tf ltr"><span class="tfsechead ltr"><span class="ltr"><a target="_blank" href="https://public.etcbc.org/targum/neofiti_base/Genesis/1&amp;version=0.0.1-alpha" title="Show this on the website" sec="neofiti_base@Genesis:1">neofiti_base@Genesis:1</a></span></span></td><td class="tf ltr"></td><td class="tf ltr"></td><td class="tf ltr"><span class=" ubd pl-mode"></span></td><td class="tf ltr"><span class=" ubd pl-mode"><span class="plain   hl" ><span class="txtu">פלחן</span></span></span></td></tr>
# <tr class="tf ltr"><td class="tf ltr">10</td><td class="tf ltr"><span class="tfsechead ltr"><span class="ltr"><a target="_blank" href="https://public.etcbc.org/targum/neofiti_base/Genesis/1&amp;version=0.0.1-alpha" title="Show this on the website" sec="neofiti_base@Genesis:1">neofiti_base@Genesis:1</a></span></span></td><td class="tf ltr"></td><td class="tf ltr"></td><td class="tf ltr"><span class=" ubd pl-mode"></span></td><td class="tf ltr"><span class=" ubd pl-mode"><span class="plain   hl" ><span class="txtu">צמחין</span></span></span></td></tr>
# <tr class="tf ltr"><td class="tf ltr">11</td><td class="tf ltr"><span class="tfsechead ltr"><span class="ltr"><a target="_blank" href="https://public.etcbc.org/targum/neofiti_base/Genesis/1&amp;version=0.0.1-alpha" title="Show this on the website" sec="neofiti_base@Genesis:1">neofiti_base@Genesis:1</a></span></span></td><td class="tf ltr"></td><td class="tf ltr"></td><td class="tf ltr"><span class=" ubd pl-mode"></span></td><td class="tf ltr"><span class=" ubd pl-mode"><span class="plain   hl" ><span class="txtu">אילנין</span></span></span></td></tr>
# <tr class="tf ltr"><td class="tf ltr">12</td><td class="tf ltr"><span class="tfsechead ltr"><span class="ltr"><a target="_blank" href="https://public.etcbc.org/targum/neofiti_base/Genesis/1&amp;version=0.0.1-alpha" title="Show this on the website" sec="neofiti_base@Genesis:1">neofiti_base@Genesis:1</a></span></span></td><td class="tf ltr"></td><td class="tf ltr"></td><td class="tf ltr"><span class=" ubd pl-mode"></span></td><td class="tf ltr"><span class=" ubd pl-mode"><span class="plain   hl" ><span class="txtu">תהומא</span></span></span></td></tr>
# <tr class="tf ltr"><td class="tf ltr">13</td><td class="tf ltr"><span class="tfsechead ltr"><span class="ltr"><a target="_blank" href="https://public.etcbc.org/targum/neofiti_base/Genesis/1&amp;version=0.0.1-alpha" title="Show this on the website" sec="neofiti_base@Genesis:1">neofiti_base@Genesis:1</a></span></span></td><td class="tf ltr"></td><td class="tf ltr"></td><td class="tf ltr"><span class=" ubd pl-mode"></span></td><td class="tf ltr"><span class=" ubd pl-mode"><span class="plain   hl" ><span class="txtu">רוח</span></span></span></td></tr>
# <tr class="tf ltr"><td class="tf ltr">14</td><td class="tf ltr"><span class="tfsechead ltr"><span class="ltr"><a target="_blank" href="https://public.etcbc.org/targum/neofiti_base/Genesis/1&amp;version=0.0.1-alpha" title="Show this on the website" sec="neofiti_base@Genesis:1">neofiti_base@Genesis:1</a></span></span></td><td class="tf ltr"></td><td class="tf ltr"></td><td class="tf ltr"><span class=" ubd pl-mode"></span></td><td class="tf ltr"><span class=" ubd pl-mode"><span class="plain   hl" ><span class="txtu">חמין</span></span></span></td></tr>
# <tr class="tf ltr"><td class="tf ltr">15</td><td cl

# %%
A.table(results, start=8, end=13, skipCols="1 2")
# Out:
# <table><tr class="tf ltr"><th class="tf ltr">n</th><th class="tf ltr">p</th><th class="tf ltr">text</th><th class="tf">book</th><th class="tf">chapter</th><th class="tf">word</th></tr>
# <tr class="tf ltr"><td class="tf ltr">8</td><td class="tf ltr"><span class="tfsechead ltr"><span class="ltr"><a target="_blank" href="https://public.etcbc.org/targum/neofiti_base/Genesis/1&amp;version=0.0.1-alpha" title="Show this on the website" sec="neofiti_base@Genesis:1">neofiti_base@Genesis:1</a></span></span></td><td class="tf ltr"></td><td class="tf ltr"></td><td class="tf ltr"><span class=" ubd pl-mode"></span></td><td class="tf ltr"><span class=" ubd pl-mode"><span class="plain   hl" ><span class="txtu">כל</span></span></span></td></tr>
# <tr class="tf ltr"><td class="tf ltr">9</td><td class="tf ltr"><span class="tfsechead ltr"><span class="ltr"><a target="_blank" href="https://public.etcbc.org/targum/neofiti_base/Genesis/1&amp;version=0.0.1-alpha" title="Show this on the website" sec="neofiti_base@Genesis:1">neofiti_base@Genesis:1</a></span></span></td><td class="tf ltr"></td><td class="tf ltr"></td><td class="tf ltr"><span class=" ubd pl-mode"></span></td><td class="tf ltr"><span class=" ubd pl-mode"><span class="plain   hl" ><span class="txtu">פלחן</span></span></span></td></tr>
# <tr class="tf ltr"><td class="tf ltr">10</td><td class="tf ltr"><span class="tfsechead ltr"><span class="ltr"><a target="_blank" href="https://public.etcbc.org/targum/neofiti_base/Genesis/1&amp;version=0.0.1-alpha" title="Show this on the website" sec="neofiti_base@Genesis:1">neofiti_base@Genesis:1</a></span></span></td><td class="tf ltr"></td><td class="tf ltr"></td><td class="tf ltr"><span class=" ubd pl-mode"></span></td><td class="tf ltr"><span class=" ubd pl-mode"><span class="plain   hl" ><span class="txtu">צמחין</span></span></span></td></tr>
# <tr class="tf ltr"><td class="tf ltr">11</td><td class="tf ltr"><span class="tfsechead ltr"><span class="ltr"><a target="_blank" href="https://public.etcbc.org/targum/neofiti_base/Genesis/1&amp;version=0.0.1-alpha" title="Show this on the website" sec="neofiti_base@Genesis:1">neofiti_base@Genesis:1</a></span></span></td><td class="tf ltr"></td><td class="tf ltr"></td><td class="tf ltr"><span class=" ubd pl-mode"></span></td><td class="tf ltr"><span class=" ubd pl-mode"><span class="plain   hl" ><span class="txtu">אילנין</span></span></span></td></tr>
# <tr class="tf ltr"><td class="tf ltr">12</td><td class="tf ltr"><span class="tfsechead ltr"><span class="ltr"><a target="_blank" href="https://public.etcbc.org/targum/neofiti_base/Genesis/1&amp;version=0.0.1-alpha" title="Show this on the website" sec="neofiti_base@Genesis:1">neofiti_base@Genesis:1</a></span></span></td><td class="tf ltr"></td><td class="tf ltr"></td><td class="tf ltr"><span class=" ubd pl-mode"></span></td><td class="tf ltr"><span class=" ubd pl-mode"><span class="plain   hl" ><span class="txtu">תהומא</span></span></span></td></tr>
# <tr class="tf ltr"><td class="tf ltr">13</td><td class="tf ltr"><span class="tfsechead ltr"><span class="ltr"><a target="_blank" href="https://public.etcbc.org/targum/neofiti_base/Genesis/1&amp;version=0.0.1-alpha" title="Show this on the website" sec="neofiti_base@Genesis:1">neofiti_base@Genesis:1</a></span></span></td><td class="tf ltr"></td><td class="tf ltr"></td><td class="tf ltr"><span class=" ubd pl-mode"></span></td><td class="tf ltr"><span class=" ubd pl-mode"><span class="plain   hl" ><span class="txtu">רוח</span></span></span></td></tr></table>

# %%
i = 0

for s in F.otype.s('segment'):
    print('T.text default', T.text(s))
    print('segment', F.segment_utf8.v(s))

    # 1. Volledige originele vocalisatie
    print("text-orig-full", T.text(s, fmt="text-orig-full"))

    # 2. Lexicale vorm (lemma's) in origineel schrift
    #print(T.text(s, fmt="fmt:lex-orig-full"))

    # 3. Consonanten (medeklinkers) in origineel schrift
    print('text-cons', T.text(s, fmt="text-cons"))

    # 4. Volledige transliteratie (Latijns schrift met klinkers)
    print("text-trans-full", T.text(s, fmt="text-trans-full"))

    # 5. Consonanten-transliteratie (alleen medeklinkers in Latijns schrift)
    print(T.text(s, fmt="text-trans-cons"))

    print()
    i += 1

    if i > 100:
        break
# Out:
# T.text default איליין פיתגמיא די מליל משׁה עם כל ישׁראל בעבר יורדנא עני משׁה ואמר להון הלא במדבר בטורא דסיני איתיהיבת לכון אוריתא ובמישׁרא דמואב איתפרשׁת לכון כמא נסין וגבורן עבד לכון מימרא דייי כד הויתון קיימין עלגיףגיף ימא דסוף איתבזע ימא מןקומיכון ואתעבד תרתיעשׁרי איסטרטין מן אסטרא חד לכל שׁבט ארגזתון קומוי על ימא וסרבתון על ימא דסוף עלעיסקעלעיסק יליליא
# segment איליין פיתגמיא די מליל משׁה עם כל ישׁראל בעבר יורדנא עני משׁה ואמר להון הלא במדברא בטורא דסיני איתיהיבת לכון אוריתא ובמישׁרא דמואב איתפרשׁת לכון כמא נסין וגבורן עבד לכון מימרא דייי כד הויתון קיימין על גיף ימא דסוף איתבזע ימא מן קומיכון ואתעבד תרתי עשׁרי איסטרטין מן אסטרא חד לכל שׁבט ארגזתון קומוי על ימא וסרבתון על ימא דסוף על עיסק יליליא
# text-orig-full איליין פיתגמיא די מליל משׁה עם כל ישׁראל בעבר יורדנא עני משׁה ואמר להון הלא במדבר בטורא דסיני איתיהיבת לכון אוריתא ובמישׁרא דמואב איתפרשׁת לכון כמא נסין וגבורן עבד לכון מימרא דייי כד הויתון קיימין עלגיףגיף ימא דסוף איתבזע ימא מןקומיכון ואתעבד תרתיעשׁרי איסטרטין מן אסטרא חד לכל שׁבט ארגזתון קומוי על ימא וסרבתון על ימא דסוף עלעיסקעלעיסק יליליא
# text-cons איליין פיתגמיא די מליל משׁה עם כל ישׁראל בעבר יורדנא עני משׁה ואמר להון הלא במדבר בטורא דסיני איתיהיבת לכון אוריתא ובמישׁרא דמואב איתפרשׁת לכון כמא נסין וגבורן עבד לכון מימרא דייי כד הויתון קיימין עלגיףגיף ימא דסוף איתבזע ימא מןקומיכון ואתעבד תרתיעשׁרי איסטרטין מן אסטרא חד לכל שׁבט ארגזתון קומוי על ימא וסרבתון על ימא דסוף עלעיסקעלעיסק יליליא
# text-trans-full >JLJJn PJTGMJ> DJ MLJL MCH <m KL JCR>L B<BR JWRDN> <NJ MCH W>MR LHWn HL> BMDBR BVWR> DSJNJ >JTJHJBT LKWn >WRJT> WBMJCR> DMW>B >JTPRCT LKWn KM> NSJn WGBWRn <BD LKWn MJMR> DJJJ KD HWJTWn QJJMJn <LGJpGJp JM> DSWp >JTBZ< JM> MNQWMJKWN W>T<BD TRTJ<CRJ >JSVRVJn Mn >SVR> XD LKL CBV >RGZTWn QWMWJ <L JM> WSRBTWn <L JM> DSWp <L<JSQ<L<JSQ JLJLJ>
# >JLJJn PJTGMJ> DJ MLJL MCH <m KL JCR>L B<BR JWRDN> <NJ MCH W>MR LHWn HL> BMDBR BVWR> DSJNJ >JTJHJBT LKWn >WRJT> WBMJCR> DMW>B >JTPRCT LKWn KM> NSJn WGBWRn <BD LKWn MJMR> DJJJ KD HWJTWn QJJMJn <LGJpGJp JM> DSWp >JTBZ< JM> MNQWMJKWN W>T<BD TRTJ<CRJ >JSVRVJn Mn >SVR> XD LKL CBV >RGZTWn QWMWJ <L JM> WSRBTWn <L JM> DSWp <L<JSQ<L<JSQ JLJLJ>
#
# T.text default דאשׁתלחתון
# segment דאשׁתלחתון
# text-orig-full דאשׁתלחתון
# text-cons דאשׁתלחתון
# text-trans-full D>CTLXTWN
# D>CTLXTWN
#
# T.text default מהלך חדעשׁר יומין מן טורא דחורב אורח טורא דגבלא עד
# segment מהלך חד עשׁר יומין מן טורא דחורב אורח טורא דגבלא עד רקם
# text-orig-full מהלך חדעשׁר יומין מן טורא דחורב אורח טורא דגבלא עד
# text-cons מהלך חדעשׁר יומין מן טורא דחורב אורח טורא דגבלא עד
# text-trans-full MHLk XD<CR JWMJn Mn VWR> DXWRB >WRX VWR> DGBL> <D
# MHLk XD<CR JWMJn Mn VWR> DXWRB >WRX VWR> DGBL> <D
#
# T.text default רקםרדגיעא
# segment רגיעא
# text-orig-full רקםרדגיעא
# text-cons רקםרדגיעא
# text-trans-full RQmRDGJ<>
# RQmRDGJ<>
#
# T.text default על דחטיתון וארגזתון קומוי אתעכבתון והליכתון יתהון לארבעין שׁנין
# segment על דחטיתון וארגזתון קומוי אתעכבתון והליכתון יתהון לארבעין שׁנין
# text-orig-full על דחטיתון וארגזתון קומוי אתעכבתון והליכתון יתהון לארבעין שׁנין
# text-cons על דחטיתון וארגזתון קומוי אתעכבתון והליכתון יתהון לארבעין שׁנין
# text-trans-full <L DXVJTWn W>RGZTWn QWMWJ >T<KBTWn WHLJKTWN JTHWn L>RB<JN CNJn
# <L DXVJTWn W>RGZTWn QWMWJ >T<KBTWn WHLJKTWN JTHWn L>RB<JN CNJn
#
# T.text default ברבת בני עמון באפרכיין
# segment ברבת בני עמון באפרכיין
# text-orig-full ברבת בני עמון באפרכיין
# text-cons ברבת בני עמון באפרכיין
# text-trans-full BRBT BNJ <MWn B>PRKJJN
# BRBT BNJ <MWn B>PRKJJN
#
# T.text default ושׁרינן בחילא בכיין על חובינן ומתוודין על חובינן על דאיתדבקנן לפלחי טעוותא פעור
# segment ושׁרינן בחילא בכיין על חובינן ומתוודין על חובינן על דאיתדבקנן לפלחי טעוותא פעור
# text-orig-full ושׁרינן בחילא בכיין על חובינן ומתוודין על חובינן על דאיתדבקנן לפלחי טעוותא פעור
# text-cons ושׁרינן בחילא בכיין על חובינן ומתוודין על חובינן על דאיתדבקנן לפלחי טעוותא פעור
# text-trans-full WCRJNn BXJL> BKJJn <L XWBJNn WMTWWDJn <L XWBJNn <L D>JTDBQNn LPLXJ V<WWT> P<WR
# WCRJNn BXJL> BKJJn <L XWBJNn WMTWWDJn <L XWBJNn <L D>JTDBQNn LPLXJ V<WWT> P<WR
#
# T.text default ובמדמככון ווב
# segment ובמדמככון ובקומיכון
# text-orig-full ובמדמככון ווב
# text-cons ובמדמככון ווב
# text-trans-full WBMDMKKWN WWB
# WBMDMKKWN WWB
#
# T.text default ומשׁלם לסנאוי אגר קלילן דאית בידיהון בעלמא הדין מןבגלל למשׁיציא יתהון לעלמא דאתי ולא משׁהא למשׁלמא לסנאוי אגר מצוון קלילן דאית בידיהון בעלמא הדין
# segment ומשׁלם לסנאוי אגר קלילן דאית בידיהון בעלמא הדין מן בגלל למשׁיציא יתהון לעלמא דאתי ולא משׁהא למשׁלמא לסנאוי אגר מצוון קלילן דאית בידיהון בעלמא הדין
# text-orig-full ומשׁלם לסנאוי אגר קלילן דאית בידיהון בעלמא הדין מןבגלל למשׁיציא יתהון לעלמא דאתי ולא משׁהא למשׁלמא לסנאוי אגר מצוון קלילן דאית בידיהון בעלמא הדין
# text-cons ומשׁלם לסנאוי אגר קלילן דאית בידיהון בעלמא הדין מןבגלל למשׁיציא יתהון לעלמא דאתי ולא משׁהא למשׁלמא לסנאוי אגר מצוון קלילן דאית בידיהון בעלמא הדין
# text-trans-full WMCLm LSN>WJ >GR QLJLn D>JT BJDJHWn B<LM> HDJn MnBGLL LMCJYJ> JTHWn L<LM> D>TJ WL> MCH> LMCLM> LSN>WJ >GR MYWWn QLJLn D>JT BJDJHWn B<LM> HDJn
# WMCLm LSN>WJ >GR QLJLn D>JT BJDJHWn B<LM> HDJn MnBGLL LMCJYJ> JTHWn L<LM> D>TJ WL> MCH> LMCLM> LSN>WJ >GR MYWWn QLJLn D>JT BJDJHWn B<LM> HDJn
#
# T.text default ומן תמרא עבדי דובשׁא
# segment ומן תמרא עבדי דובשׁא
# text-orig-full ומן תמרא עבדי דובשׁא
# text-cons ומן תמרא עבדי דובשׁא
# text-trans-full WMn TMR> <BDJ DWBC>
# WMn TMR> <BDJ DWBC>
#
# T.text default רב ושׁליט
# segment רב ושׁליט
# text-orig-full רב ושׁליט
# text-cons רב ושׁליט
# text-trans-full RB WCLJV
# RB WCLJV
#
# T.text default וחילופיהון
# segment וחילופיהון
# text-orig-full וחילופיהון
# text-cons וחילופיהון
# text-trans-full WXJLWPJHWn
# WXJLWPJHWn
#
# T.text default דםמרחק מן קודשׁיא ודכיד מן קודשׁיא
# segment דמרחק מן קודשׁיא ודדכי מן קודשׁיא
# text-orig-full דםמרחק מן קודשׁיא ודכיד מן קודשׁיא
# text-cons דםמרחק מן קודשׁיא ודכיד מן קודשׁיא
# text-trans-full DMMRXQ Mn QWDCJ> WDKJD Mn QWDCJ>
# DMMRXQ Mn QWDCJ> WDKJD Mn QWDCJ>
#
# T.text default דפסיל מן קורבנא וכשׁרד למקרבא כחדא ייכלון יתיה כבישׁריה דתביא ואיילאד
# segment דפסיל מן קורבנא ודכשׁר למקרבא כחדא ייכלון יתיה כבישׁריה דטביא ודאיילא
# text-orig-full דפסיל מן קורבנא וכשׁרד למקרבא כחדא ייכלון יתיה כבישׁריה דתביא ואיילאד
# text-cons דפסיל מן קורבנא וכשׁרד למקרבא כחדא ייכלון יתיה כבישׁריה דתביא ואיילאד
# text-trans-full DPSJL Mn QWRBN> WKCRD LMQRB> KXD> JJKLWn JTJH KBJCRJH DTBJ> W>JJL>D
# DPSJL Mn QWRBN> WKCRD LMQRB> KXD> JJKLWn JTJH KBJCRJH DTBJ> W>JJL>D
#
# T.text default לא תעבדון חברין חברין דףולחן נוכראין ולא תשׁוון קרחה על ביתאפיכון לתמא נפשׁ דמית
# segment לא תעבדון חברין חברין דפולחן נוכראין ולא תשׁוון קרחה על בית אפיכון לטמא נפשׁ דמית
# text-orig-full לא תעבדון חברין חברין דףולחן נוכראין ולא תשׁוון קרחה על ביתאפיכון לתמא נפשׁ דמית
# text-cons לא תעבדון חברין חברין דףולחן נוכראין ולא תשׁוון קרחה על ביתאפיכון לתמא נפשׁ דמית
# text-trans-full L> T<BDWn XBRJn XBRJn DPWLXn NWKR>Jn WL> TCWWn QRXH <L BJT>PJKWn LTM> NPC DMJT
# L> T<BDWn XBRJn XBRJn DPWLXn NWKR>Jn WL> TCWWn QRXH <L BJT>PJKWn LTM> NPC DMJT
#
# T.text default והעטלף וחפרפרא
# segment והעטלף וחפרפרא
# text-orig-full והעטלף וחפרפרא
# text-cons והעטלף וחפרפרא
# text-trans-full WH<VLp WXPRPR>
# WH<VLp WXPRPR>
#
# T.text default עמי בני ישׁראל מעשׁרא תעשׁרון מכל עללתכון דאתון זרעין עלאפיאפי ברא וכנשׁין עללן בכל שׁנא ושׁנא עמי בני ישׁראל לית אתון רשׁאין למעשׁרא ומיכולל פרי שׁנא על פרי שׁנא
# segment עמי בני ישׁראל מעשׁרא תעשׁרון מכל עללתכון דאתון זרעין על אפי ברא וכנשׁין עללן בכל שׁנא ושׁנא עמי בני ישׁראל לית אתון רשׁאין למעשׁרא ולמיכול פרי שׁנא על פרי שׁנא
# text-orig-full עמי בני ישׁראל מעשׁרא תעשׁרון מכל עללתכון דאתון זרעין עלאפיאפי ברא וכנשׁין עללן בכל שׁנא ושׁנא עמי בני ישׁראל לית אתון רשׁאין למעשׁרא ומיכולל פרי שׁנא על פרי שׁנא
# text-cons עמי בני ישׁראל מעשׁרא תעשׁרון מכל עללתכון דאתון זרעין עלאפיאפי ברא וכנשׁין עללן בכל שׁנא ושׁנא עמי בני ישׁראל לית אתון רשׁאין למעשׁרא ומיכולל פרי שׁנא על פרי שׁנא
# text-trans-full <MJ BNJ JCR>L M<CR> T<CRWn MKL <LLTKWn D>TWn ZR<Jn <L>PJ>PJ BR> WKNCJN <LLn BKL CN> WCN> <MJ BNJ JCR>L LJT >TWn RC>Jn LM<CR> WMJKWLL PRJ CN> <L PRJ CN>
# <MJ BNJ JCR>L M<CR> T<CRWn MKL <LLTKWn D>TWn ZR<Jn <L>PJ>PJ BR> WKNCJN <LLn BKL CN> WCN> <MJ BNJ JCR>L LJT >TWn RC>Jn LM<CR> WMJKWLL PRJ CN> <L PRJ CN>
#
# T.text default מקלקל מיליהון דדכאי בשׁעת דינהון
# segment מקלקל מיליהון דדכאי בשׁעת דינהון
# text-orig-full מקלקל מיליהון דדכאי בשׁעת דינהון
# text-cons מקלקל מיליהון דדכאי בשׁעת דינהון
# text-trans-full MQLQL MJLJHWn DDK>J BC<T DJNHWn
# MQLQL MJLJHWn DDK>J BC<T DJNHWn
#
# T.text default בין דם דקטולין ובין דם דבתולין בין מכתשׁ צרעא למכתשׁ נתקא
# segment בין דם דקטולין ובין דם דבתולין בין מכתשׁ צרעא למכתשׁ נתקא
# text-orig-full בין דם דקטולין ובין דם דבתולין בין מכתשׁ צרעא למכתשׁ נתקא
# text-cons בין דם דקטולין ובין דם דבתולין בין מכתשׁ צרעא למכתשׁ נתקא
# text-trans-full BJn Dm DQVWLJn WBJn Dm DBTWLJN BJn MKTC YR<> LMKTC NTQ>
# BJn Dm DQVWLJn WBJn Dm DBTWLJN BJn MKTC YR<> LMKTC NTQ>
#
# T.text default יחם ירתע
# segment יחם ירתע
# text-orig-full יחם ירתע
# text-cons יחם ירתע
# text-trans-full JXm JRT<
# JXm JRT<
#
# T.text default ופתחה לך ויפתח לך פלוותא
# segment ופתחה לך ויפתח לך פלוותא
# text-orig-full ופתחה לך ויפתח לך פלוותא
# text-cons ופתחה לך ויפתח לך פלוותא
# text-trans-full WPTXH Lk WJPTX Lk PLWWT>
# WPTXH Lk WJPTX Lk PLWWT>
#
# T.text default עניתה דיהבת רשׁותך עלה
# segment עניתה דיהבת רשׁותך עלה
# text-orig-full עניתה דיהבת רשׁותך עלה
# text-cons עניתה דיהבת רשׁותך עלה
# text-trans-full <NJTH DJHBT RCWTk <LH
# <NJTH DJHBT RCWTk <LH
#
# T.text default הקם תקים עמו מפרק תפרוק עימיה ומטען תטען עימיה
# segment הקם תקים עמו מפרק תפרוק עימיה ומטען תטען עימיה
# text-orig-full הקם תקים עמו מפרק תפרוק עימיה ומטען תטען עימיה
# text-cons הקם תקים עמו מפרק תפרוק עימיה ומטען תטען עימיה
# text-trans-full HQm TQJm <MW MPRQ TPRWQ <JMJH WMV<n TV<n <JMJH
# HQm TQJm <MW MPRQ TPRWQ <JMJH WMV<n TV<n <JMJH
#
# T.text default מעקה גיפוף
# segment מעקה גיפוף
# text-orig-full מעקה גיפוף
# text-cons מעקה גיפוף
# text-trans-full M<QH GJPWP
# M<QH GJPWP
#
# T.text default גדילים גדילן דציצית
# segment גדילים גדילן דציצית
# text-orig-full גדילים גדילן דציצית
# text-cons גדילים גדילן דציצית
# text-trans-full GDJLJM GDJLn DYJYJT
# GDJLJM GDJLn DYJYJT
#
# T.text default לא שׁכחו סהדין לתלייתא
# segment לא אשׁכחו סהדין לטלייתא
# text-orig-full לא שׁכחו סהדין לתלייתא
# text-cons לא שׁכחו סהדין לתלייתא
# text-trans-full L> CKXW SHDJn LTLJJT>
# L> CKXW SHDJn LTLJJT>
#
# T.text default נקי יהיה זקיק יהא לביתיה
# segment נקי יהיה זקיק יהא לביתיה
# text-orig-full נקי יהיה זקיק יהא לביתיה
# text-cons נקי יהיה זקיק יהא לביתיה
# text-trans-full NQJ JHJH ZQJQ JH> LBJTJH
# NQJ JHJH ZQJQ JH> LBJTJH
#
# T.text default עמי עמי בני ישׁראל לא תמשׁכנון ריחיא ורכבא ארום צרכי נפשׁא הוא ממשׁכן ולא תהוון אסרין חתנין
# segment עמי עמי בני ישׁראל לא תמשׁכנון ריחיא ורכבא ארום צרכי נפשׁא הוא ממשׁכן ולא תהוון אסרין חתנין
# text-orig-full עמי עמי בני ישׁראל לא תמשׁכנון ריחיא ורכבא ארום צרכי נפשׁא הוא ממשׁכן ולא תהוון אסרין חתנין
# text-cons עמי עמי בני ישׁראל לא תמשׁכנון ריחיא ורכבא ארום צרכי נפשׁא הוא ממשׁכן ולא תהוון אסרין חתנין
# text-trans-full <MJ <MJ BNJ JCR>L L> TMCKNWn RJXJ> WRKB> >RWm YRKJ NPC> HW> MMCKn WL> THWWn >SRJn XTNJn
# <MJ <MJ BNJ JCR>L L> TMCKNWn RJXJ> WRKB> >RWm YRKJ NPC> HW> MMCKn WL> THWWn >SRJn XTNJn
#
# T.text default וכליין
# segment וכליין
# text-orig-full וכליין
# text-cons וכליין
# text-trans-full WKLJJN
# WKLJJN
#
# T.text default ארום כל דעבד איליין כפר בחיי עלמא דאתי
# segment ארום כל דעבד איליין כפר בחיי עלמא דאתי
# text-orig-full ארום כל דעבד איליין כפר בחיי עלמא דאתי
# text-cons ארום כל דעבד איליין כפר בחיי עלמא דאתי
# text-trans-full >RWm KL D<BD >JLJJn KPR BXJJ <LM> D>TJ
# >RWm KL D<BD >JLJJn KPR BXJJ <LM> D>TJ
#
# T.text default עמי בני ישׁראל לא תזממון תורא
# segment עמי בני ישׁראל לא תזממון תורא
# text-orig-full עמי בני ישׁראל לא תזממון תורא
# text-cons עמי בני ישׁראל לא תזממון תורא
# text-trans-full <MJ BNJ JCR>L L> TZMMWn TWR>
# <MJ BNJ JCR>L L> TZMMWn TWR>
#
# T.text default בשׁעתה
# segment בשׁעתה
# text-orig-full בשׁעתה
# text-cons בשׁעתה
# text-trans-full BC<TH
# BC<TH
#
# T.text default דרידיה
# segment דרידיה
# text-orig-full דרידיה
# text-cons דרידיה
# text-trans-full DRJDJH
# DRJDJH
#
# T.text default חלוץ הנעל שׁלופי סנדלא ומבתלי מצוותא דיבמה
# segment חלוץ הנעל שׁלופי סנדלא ומבטלי מצוותא דיבמה
# text-orig-full חלוץ הנעל שׁלופי סנדלא ומבתלי מצוותא דיבמה
# text-cons חלוץ הנעל שׁלופי סנדלא ומבתלי מצוותא דיבמה
# text-trans-full XLWY HN<L CLWPJ SNDL> WMBTLJ MYWWT> DJBMH
# XLWY HN<L CLWPJ SNDL> WMBTLJ MYWWT> DJBMH
#
# T.text default מתקלין רברבין למיהוי זבן
# segment מתקלין רברבין למיהוי זבן
# text-orig-full מתקלין רברבין למיהוי זבן
# text-cons מתקלין רברבין למיהוי זבן
# text-trans-full MTQLJn RBRBJn LMJHWJ ZBn
# MTQLJn RBRBJn LMJHWJ ZBn
#
# T.text default בהון
# segment בהון
# text-orig-full בהון
# text-cons בהון
# text-trans-full BHWN
# BHWN
#
# T.text default ומתקלין זעירן למיהוי מזבין בהון
# segment ומתקלין זעירן למיהוי מזבין בהון
# text-orig-full ומתקלין זעירן למיהוי מזבין בהון
# text-cons ומתקלין זעירן למיהוי מזבין בהון
# text-trans-full WMTQLJn Z<JRn LMJHWJ MZBJn BHWn
# WMTQLJn Z<JRn LMJHWJ MZBJn BHWn
#
# text-trans-full LLSMJ>
# LLSMJ>
#
# T.text default ליט
# segment ליט יהוי גברא
# text-orig-full ליט
# text-cons ליט
# text-trans-full LJV
# LJV
#
# T.text default יהוי גברא משׁמישׁודמשׁמישׁ עם חביבתיה
# segment עם חביבתיה
# text-orig-full יהוי גברא משׁמישׁודמשׁמישׁ עם חביבתיה
# text-cons יהוי גברא משׁמישׁודמשׁמישׁ עם חביבתיה
# text-trans-full JHWJ GBR> MCMJCWDMCMJC <m XBJBTJH
# JHWJ GBR> MCMJCWDMCMJC <m XBJBTJH
#
# T.text default ובריכין תהוון כל בני ישׁראל בזמן דמהלכין ומעלין בבתי כנישׁתהון ובבתימדרשׁיהון
# segment ובריכין תהוון כל בני ישׁראל בזמן דמהלכין ומעלין בבתי כנישׁתהון ובבתי מדרשׁיהון
# text-orig-full ובריכין תהוון כל בני ישׁראל בזמן דמהלכין ומעלין בבתי כנישׁתהון ובבתימדרשׁיהון
# text-cons ובריכין תהוון כל בני ישׁראל בזמן דמהלכין ומעלין בבתי כנישׁתהון ובבתימדרשׁיהון
# text-trans-full WBRJKJn THWWn KL BNJ JCR>L BZMn DMHLKJN WM<LJN BBTJ KNJCTHWn WBBTJMDRCJHWN
# WBRJKJn THWWn KL BNJ JCR>L BZMn DMHLKJN WM<LJN BBTJ KNJCTHWn WBBTJMDRCJHWN
#
# T.text default יחסלנו יקרסם
# segment יחסלנו יקרסם
# text-orig-full יחסלנו יקרסם
# text-cons יחסלנו יקרסם
# text-trans-full JXSLNW JQRSm
# JXSLNW JQRSm
#
# T.text default מהתענג מן פירנקו ומן חטוונא תבעשׁ
# segment ומן חטוונא תבעשׁ
# text-orig-full מהתענג מן פירנקו ומן חטוונא תבעשׁ
# text-cons מהתענג מן פירנקו ומן חטוונא תבעשׁ
# text-trans-full MHT<NG Mn PJRNQW WMn XVWWN> TB<C
# MHT<NG Mn PJRNQW WMn XVWWN> TB<C
#
# T.text default דלא יהוי בכון גבר דליביה מהרהר בחטאה דהוא דמי לשׁורשׁ קביע
# segment דלא יהוי בכון גבר דליביה מהרהר בחטאה דהוא דמי לשׁורשׁ קביע
# text-orig-full דלא יהוי בכון גבר דליביה מהרהר בחטאה דהוא דמי לשׁורשׁ קביע
# text-cons דלא יהוי בכון גבר דליביה מהרהר בחטאה דהוא דמי לשׁורשׁ קביע
# text-trans-full DL> JHWJ BKWn GBR DLJBJH MHRHR BXV>H DHW> DMJ LCWRC QBJ<
# DL> JHWJ BKWn GBR DLJBJH MHRHR BXV>H DHW> DMJ LCWRC QBJ<
#
# T.text default ארעאבארעא
# segment בארעא
# text-orig-full ארעאבארעא
# text-cons ארעאבארעא
# text-trans-full >R<>B>R<>
# >R<>B>R<>
#
# T.text default ארום רישׁיה דחיטאהחיתאה
# segment ארום רישׁיה דחיטאה
# text-orig-full ארום רישׁיה דחיטאהחיתאה
# text-cons ארום רישׁיה דחיטאהחיתאה
# text-trans-full >RWm RJCJH DXJV>HXJT>H
# >RWm RJCJH DXJV>HXJT>H
#
# T.text default חיילחלי
# segment חייל
# text-orig-full חיילחלי
# text-cons חיילחלי
# text-trans-full XJJLXLJ
# XJJLXLJ
#
# T.text default כדובשׁא וסופיה מריר כלענתא דמותא
# segment כדובשׁא וסופיה מריר כלענתא דמותא
# text-orig-full כדובשׁא וסופיה מריר כלענתא דמותא
# text-cons כדובשׁא וסופיה מריר כלענתא דמותא
# text-trans-full KDWBC> WSWPJH MRJR KL<NT> DMWT>
# KDWBC> WSWPJH MRJR KL<NT> DMWT>
#
# T.text default לא בשׁמיא היא אוריתא למימר אלואי הוה לנא חד כמשׁה נביאה דיסוק לשׁמיא וייתי יתה וגו
# segment לא בשׁמיא היא אוריתא למימר אלואי הוה לנא חד כמשׁה נביאה דיסוק לשׁמיא וייתי יתה וגו
# text-orig-full לא בשׁמיא היא אוריתא למימר אלואי הוה לנא חד כמשׁה נביאה דיסוק לשׁמיא וייתי יתה וגו
# text-cons לא בשׁמיא היא אוריתא למימר אלואי הוה לנא חד כמשׁה נביאה דיסוק לשׁמיא וייתי יתה וגו
# text-trans-full L> BCMJ> HJ> >WRJT> LMJMR >LW>J HWH LN> XD KMCH NBJ>H DJSWQ LCMJ> WJJTJ JTH WGW
# L> BCMJ> HJ> >WRJT> LMJMR >LW>J HWH LN> XD KMCH NBJ>H DJSWQ LCMJ> WJJTJ JTH WGW
#
# T.text default כיון דימטא קיציה דמשׁה
# segment כיון דמטא קיציה דמשׁה
# text-orig-full כיון דימטא קיציה דמשׁה
# text-cons כיון דימטא קיציה דמשׁה
# text-trans-full KJWn DJMV> QJYJH DMCH
# KJWn DJMV> QJYJH DMCH
#
# T.text default למסתלקא
# segment למסתלקא
# text-orig-full למסתלקא
# text-cons למסתלקא
# text-trans-full LMSTLQ>
# LMSTLQ>
#
# T.text default מןגו עלמא אמר מאי אנא מסהיד בעמא האיליין מילין דלא טעמא מייתו מסהיד אנא בהון שׁמיא וארעא דלא כליין בעלמא
# segment מן גו עלמא אמר מאי אנא מסהיד בעמא האיליין מילין דלא טעמא מייתו מסהיד אנא בהון שׁמיא וארעא דלא כליין בעלמא
# text-orig-full מןגו עלמא אמר מאי אנא מסהיד בעמא האיליין מילין דלא טעמא מייתו מסהיד אנא בהון שׁמיא וארעא דלא כליין בעלמא
# text-cons מןגו עלמא אמר מאי אנא מסהיד בעמא האיליין מילין דלא טעמא מייתו מסהיד אנא בהון שׁמיא וארעא דלא כליין בעלמא
# text-trans-full MnGW <LM> >MR M>J >N> MSHJD B<M> H>JLJJn MJLJn DL> V<M> MJJTW MSHJD >N> BHWn CMJ> W>R<> DL> KLJJn B<LM>
# MnGW <LM> >MR M>J >N> MSHJD B<M> H>JLJJn MJLJn DL> V<M> MJJTW MSHJD >N> BHWn CMJ> W>R<> DL> KLJJn B<LM>
#
# T.text default הדין
# segment הדין
# text-orig-full הדין
# text-cons הדין
# text-trans-full HDJn
# HDJn
#
# text-trans-full BRm SWPJHWn DKLJJN L<LM> D>TJ DHKN HW> KTB> MPRC W>MR VWLW CMJ> <JNJKWn W>SHJDW L>R<> MnLR< >RWm CMJ> TNN> JMSWn W>R<> KLBWC> TBLJ BRm >N> <TJD BRJ CMJ> XDTJn W>R<> XDT> JC<JH NBJ>H KD HWH MTNB> BKNJCTHWn DJCR>L <L DHWH QRJB L>R<> WRXJQ Mn CMJ> JHB CMJ<T> LCMJ> W>YJT> L>R<> DHKN HW> KTB> MPRC W>MR CM<W CMJ> W>YJTJ >R<> WMCH <L DHWH QRJB LCMJ> WRXJQ Mn >R<> JHB YJJT> LCMJ> WCMJ<T> L>R<> DHKN HW> KTB> MPRC W>MR >YJTW CMJ> WGW
# BRm SWPJHWn DKLJJN L<LM> D>TJ DHKN HW> KTB> MPRC W>MR VWLW CMJ> <JNJKWn W>SHJDW L>R<> MnLR< >RWm CMJ> TNN> JMSWn W>R<> KLBWC> TBLJ BRm >N> <TJD BRJ CMJ> XDTJn W>R<> XDT> JC<JH NBJ>H KD HWH MTNB> BKNJCTHWn DJCR>L <L DHWH QRJB L>R<> WRXJQ Mn CMJ> JHB CMJ<T> LCMJ> W>YJT> L>R<> DHKN HW> KTB> MPRC W>MR CM<W CMJ> W>YJTJ >R<> WMCH <L DHWH QRJB LCMJ> WRXJQ Mn >R<> JHB YJJT> LCMJ> WCMJ<T> L>R<> DHKN HW> KTB> MPRC W>MR >YJTW CMJ> WGW
#
# T.text default יבסם על בני ישׁראל כמיתרא אולפן אוריתי
# segment יבסם על בני ישׁראל כמיטרא אולפן אוריתי
# text-orig-full יבסם על בני ישׁראל כמיתרא אולפן אוריתי
# text-cons יבסם על בני ישׁראל כמיתרא אולפן אוריתי
# text-trans-full JBSm <L BNJ JCR>L KMJTR> >WLPn >WRJTJ
# JBSm <L BNJ JCR>L KMJTR> >WLPn >WRJTJ
#
# T.text default יתקבל
# segment יתקבל
# text-orig-full יתקבל
# text-cons יתקבל
# text-trans-full JTQBL
# JTQBL
#
# T.text default עליהון ברעוא כטלא מימר פמי כרוחיא דנשׁבין על עיסבא וככרסיסי מלקושׁא דנחתין ומרוין צימחא דארעא בירחא דניסן
# segment עליהון ברעוא כטלא מימר פמי כרוחיא דנשׁבין על עיסבא וכרסיסי מלקושׁא דנחתין ומרוין צימחא דארעא בירחא דניסן
# text-orig-full עליהון ברעוא כטלא מימר פמי כרוחיא דנשׁבין על עיסבא וככרסיסי מלקושׁא דנחתין ומרוין צימחא דארעא בירחא דניסן
# text-cons עליהון ברעוא כטלא מימר פמי כרוחיא דנשׁבין על עיסבא וככרסיסי מלקושׁא דנחתין ומרוין צימחא דארעא בירחא דניסן
# text-trans-full <LJHWn BR<W> KVL> MJMR PMJ KRWXJ> DNCBJN <L <JSB> WKKRSJSJ MLQWC> DNXTJn WMRWJN YJMX> D>R<> BJRX> DNJSn
# <LJHWn BR<W> KVL> MJMR PMJ KRWXJ> DNCBJN <L <JSB> WKKRSJSJ MLQWC> DNXTJn WMRWJN YJMX> D>R<> BJRX> DNJSn
#
# >MR MCH NBJ>H W LHWn LRCJ<J> DDMDKRJn CM> DQWDC> >RWm LJT >JPCR LXD Mn ML>KJ MRWM> LMDKR> CM> DMPRC> <DZMnZMn DHJNWn >MRJn Q Q Q TLT> ZJMNJn WMNHWN JLJp MCH WL> HWH MDKR CM> MPRC> <DZMnZMn DHWH MXNk PMJH B<CRJn WXD MJLJn D>JNJN TMNJn WXMC> >TJn WKn HW> MPRC W>MR H>ZJNW HCMJm WGW J<Rp KMVR WGW KJ Cm H WGW >MR MCH NBJ>H >RWm CM> JJJ >N> MYLJ W>TWn BNJ JCR>L HBW JQR WTWCBXT> WRWMMW L>LHKWn
#
# T.text default אמר משׁה נביאה כד סליקית למרומא חמית תמן רבון כל עלמא ייי מרבע יומיה לארבע חולקין תלת שׁעין לעי ועסיק באוריתא ותלת שׁעין עסיק בדינא ותלת שׁעין מפרנס עלמא ותלת שׁעין מזויג גבר לאיתתא תקיפא דשׁלמין וגו
# segment אמר משׁה נביאה כד סליקית למרומא חמית תמן רבון כל עלמא ייי מרבע יומיה לארבע חולקין תלת שׁעין לעי ועסיק באוריתא ותלת שׁעין עסיק בדינא ותלת שׁעין מפרנס עלמא ותלת שׁעין מזויג גבר לאיתתא תקיפא דשׁלמין וגו
# text-orig-full אמר משׁה נביאה כד סליקית למרומא חמית תמן רבון כל עלמא ייי מרבע יומיה לארבע חולקין תלת שׁעין לעי ועסיק באוריתא ותלת שׁעין עסיק בדינא ותלת שׁעין מפרנס עלמא ותלת שׁעין מזויג גבר לאיתתא תקיפא דשׁלמין וגו
# text-cons אמר משׁה נביאה כד סליקית למרומא חמית תמן רבון כל עלמא ייי מרבע יומיה לארבע חולקין תלת שׁעין לעי ועסיק באוריתא ותלת שׁעין עסיק בדינא ותלת שׁעין מפרנס עלמא ותלת שׁעין מזויג גבר לאיתתא תקיפא דשׁלמין וגו
# text-trans-full >MR MCH NBJ>H KD SLJQJT LMRWM> XMJT TMn RBWn KL <LM> JJJ MRB< JWMJH L>RB< XWLQJn TLT C<Jn L<J W<SJQ B>WRJT> WTLT C<Jn <SJQ BDJN> WTLT C<Jn MPRNS <LM> WTLT C<Jn MZWJG GBR L>JTT> TQJP> DCLMJN WGW
# >MR MCH NBJ>H KD SLJQJT LMRWM> XMJT TMn RBWn KL <LM> JJJ MRB< JWMJH L>RB< XWLQJn TLT C<Jn L<J W<SJQ B>WRJT> WTLT C<Jn <SJQ BDJN> WTLT C<Jn MPRNS <LM> WTLT C<Jn MZWJG GBR L>JTT> TQJP> DCLMJN WGW
#
# T.text default חבילו בניא עובדיהון ולא קומוי חבלין אלא להון ועל די חבלו מומא איתיהב בהון דרא עוקמא ופתלתא דשׁניין עובדוי ואוף סדרי עלמא אישׁתניו עלוי
# segment חבילו בניא עובדיהון ולא קומוי חבלין אלא להון ועל די חבלו מומא איתיהב בהון דרא עוקמא ופתלתא דשׁניין עובדוי ואוף סדרי עלמא אישׁתניו עלוי
# text-orig-full חבילו בניא עובדיהון ולא קומוי חבלין אלא להון ועל די חבלו מומא איתיהב בהון דרא עוקמא ופתלתא דשׁניין עובדוי ואוף סדרי עלמא אישׁתניו עלוי
# text-cons חבילו בניא עובדיהון ולא קומוי חבלין אלא להון ועל די חבלו מומא איתיהב בהון דרא עוקמא ופתלתא דשׁניין עובדוי ואוף סדרי עלמא אישׁתניו עלוי
# text-trans-full XBJLW BNJ> <WBDJHWn WL> QWMWJ XBLJn >L> LHWn W<L DJ XBLW MWM> >JTJHB BHWn DR> <WQM> WPTLT> DCNJJN <WBDWJ W>Wp SDRJ <LM> >JCTNJW <LWJ
# XBJLW BNJ> <WBDJHWn WL> QWMWJ XBLJn >L> LHWn W<L DJ XBLW MWM> >JTJHB BHWn DR> <WQM> WPTLT> DCNJJN <WBDWJ W>Wp SDRJ <LM> >JCTNJW <LWJ
#
# T.text default הוא אבוכון דבשׁמיא דקנא יתכון
# segment הוא אבוכון דבשׁמיא דקנא יתכון
# text-orig-full הוא אבוכון דבשׁמיא דקנא יתכון
# text-cons הוא אבוכון דבשׁמיא דקנא יתכון
# text-trans-full HW> >BWKWn DBCMJ> DQN> JTKWn
# HW> >BWKWn DBCMJ> DQN> JTKWn
#
# T.text default שׁאול לאבהתכון דרברבין מינכון באוריתא זקניך חכימיכון
# segment שׁאול לאבהתכון דרברבין מינכון באוריתא זקניך חכימיכון
# text-orig-full שׁאול לאבהתכון דרברבין מינכון באוריתא זקניך חכימיכון
# text-cons שׁאול לאבהתכון דרברבין מינכון באוריתא זקניך חכימיכון
# text-trans-full C>WL L>BHTKWn DRBRBJn MJNKWn B>WRJT> ZQNJK XKJMJKWn
# C>WL L>BHTKWn DRBRBJn MJNKWn B>WRJT> ZQNJK XKJMJKWn
#
# T.text default אקיף יתהון עם יקר שׁכינתיה אליף יתהון עשׁרתי דבריא
# segment אקיף יתהון עם יקר שׁכינתיה אליף יתהון עשׁרתי דבריא
# text-orig-full אקיף יתהון עם יקר שׁכינתיה אליף יתהון עשׁרתי דבריא
# text-cons אקיף יתהון עם יקר שׁכינתיה אליף יתהון עשׁרתי דבריא
# text-trans-full >QJp JTHWn <m JQR CKJNTJH >LJp JTHWn <CRTJ DBRJ>
# >QJp JTHWn <m JQR CKJNTJH >LJp JTHWn <CRTJ DBRJ>
#
# T.text default נטרי
# segment נטרי
# text-orig-full נטרי
# text-cons נטרי
# text-trans-full NVRJ
# NVRJ
#
# T.text default יתהון ועייני יתהון היך דשׁכינה
# segment יתהון ועייני יתהון היך דשׁכינה
# text-orig-full יתהון ועייני יתהון היך דשׁכינה
# text-cons יתהון ועייני יתהון היך דשׁכינה
# text-trans-full JTHWn W<JJNJ JTHWn HJk DCKJNH
# JTHWn W<JJNJ JTHWn HJk DCKJNH
#
# T.text default נטרי
# segment נטרי
# text-orig-full נטרי
# text-cons נטרי
# text-trans-full NVRJ
# NVRJ
#
# T.text default עמא
# segment עמא
# text-orig-full עמא
# text-cons עמא
# text-trans-full <M>
# <M>
#
# T.text default ארכיב יתהון על במתא דארעא ואניק יתהון דבשׁ מן כיפא ומשׁח יתהון מן כיף שׁמיר טינרא
# segment ארכיב יתהון על במתא דארעא ואניק יתהון דבשׁ מן כיפא ומשׁח יתהון מן כיף שׁמיר טינרא
# text-orig-full ארכיב יתהון על במתא דארעא ואניק יתהון דבשׁ מן כיפא ומשׁח יתהון מן כיף שׁמיר טינרא
# text-cons ארכיב יתהון על במתא דארעא ואניק יתהון דבשׁ מן כיפא ומשׁח יתהון מן כיף שׁמיר טינרא
# text-trans-full >RKJB JTHWn <L BMT> D>R<> W>NJQ JTHWn DBC Mn KJP> WMCX JTHWn Mn KJp CMJR VJNR>
# >RKJB JTHWn <L BMT> D>R<> W>NJQ JTHWn DBC Mn KJP> WMCX JTHWn Mn KJp CMJR VJNR>
#
# T.text default כד רכיכות דתורין ושׁמינין דעאן עם טוב דףטימין ודכרין בני מתנן וגדיין עם טוב שׁמיניהון דחיתיא אמר משׁה נביאה אין נטרין הינון בני ישׁראל מצוותא מן ענבא חדא יהוון שׁתיין כור דחמר
# segment כד רכיכות דתורין ושׁמינין דעאן עם טוב דפטימין ודכרין בני מתנן וגדיין עם טוב שׁמיניהון דחיטיא אמר משׁה נביאה אין נטרין הינון בני ישׁראל מצוותא מן ענבא חדא יהוון שׁתיין כור דחמר
# text-orig-full כד רכיכות דתורין ושׁמינין דעאן עם טוב דףטימין ודכרין בני מתנן וגדיין עם טוב שׁמיניהון דחיתיא אמר משׁה נביאה אין נטרין הינון בני ישׁראל מצוותא מן ענבא חדא יהוון שׁתיין כור דחמר
# text-cons כד רכיכות דתורין ושׁמינין דעאן עם טוב דףטימין ודכרין בני מתנן וגדיין עם טוב שׁמיניהון דחיתיא אמר משׁה נביאה אין נטרין הינון בני ישׁראל מצוותא מן ענבא חדא יהוון שׁתיין כור דחמר
# text-trans-full KD RKJKWT DTWRJn WCMJNJN D<>n <m VWB DPVJMJn WDKRJn BNJ MTNn WGDJJn <m VWB CMJNJHWn DXJTJ> >MR MCH NBJ>H >Jn NVRJn HJNWn BNJ JCR>L MYWWT> Mn <NB> XD> JHWWn CTJJn KWR DXMR
# KD RKJKWT DTWRJn WCMJNJN D<>n <m VWB DPVJMJn WDKRJn BNJ MTNn WGDJJn <m VWB CMJNJHWn DXJTJ> >MR MCH NBJ>H >Jn NVRJn HJNWn BNJ JCR>L MYWWT> Mn <NB> XD> JHWWn CTJJn KWR DXMR
#
# T.text default ועבד
# segment ועבד
# text-orig-full ועבד
# text-cons ועבד
# text-trans-full W<BD
# W<BD
#
# T.text default יתהכון
# segment יתהון
# text-orig-full יתהכון
# text-cons יתהכון
# text-trans-full JTHKWn
# JTHKWn
#
# T.text default מחלין מחלין
# segment מחלין מחלין
# text-orig-full מחלין מחלין
# text-cons מחלין מחלין
# text-trans-full MXLJn MXLJn
# MXLJn MXLJn
#
# T.text default מן כעס דאכעיסו יתיה בניא חביביא דהוו חביבין עליה היך בנין והיך בנן
# segment מן כעס דאכעיסו יתיה בניא חביביא דהוו חביבין עליה היך בנין והיך בנן
# text-orig-full מן כעס דאכעיסו יתיה בניא חביביא דהוו חביבין עליה היך בנין והיך בנן
# text-cons מן כעס דאכעיסו יתיה בניא חביביא דהוו חביבין עליה היך בנין והיך בנן
# text-trans-full Mn K<S D>K<JSW JTJH BNJ> XBJBJ> DHWW XBJBJn <LJH HJk BNJn WHJk BNn
# Mn K<S D>K<JSW JTJH BNJ> XBJBJ> DHWW XBJBJn <LJH HJk BNJn WHJk BNn
#
# T.text default ולחומי ואכילי עוף מסאב ושׁן בהמות ושׁן ד מלכוותא דמתילן בחיות ברא
# segment ולחומי ואכילי עוף מסאב
# text-orig-full ולחומי ואכילי עוף מסאב ושׁן בהמות ושׁן ד מלכוותא דמתילן בחיות ברא
# text-cons ולחומי ואכילי עוף מסאב ושׁן בהמות ושׁן ד מלכוותא דמתילן בחיות ברא
# text-trans-full WLXWMJ W>KJLJ <Wp MS>B WCN BHMWT WCN D MLKWWT> DMTJLn BXJWT BR>
# WLXWMJ W>KJLJ <Wp MS>B WCN BHMWT WCN D MLKWWT> DMTJLn BXJWT BR>
#
# T.text default ארום לא כרוחצנא רוחצנהון דאומיא ועל דחטינן וארגיזנן קומוי אתעבדו בעלידבבנא דיינין
# segment ארום לא כרוחצנא רוחצנהון דאומיא ועל דחטינן וארגיזנן קומוי אתעבדו בעלי דבבנא דיינין
# text-orig-full ארום לא כרוחצנא רוחצנהון דאומיא ועל דחטינן וארגיזנן קומוי אתעבדו בעלידבבנא דיינין
# text-cons ארום לא כרוחצנא רוחצנהון דאומיא ועל דחטינן וארגיזנן קומוי אתעבדו בעלידבבנא דיינין
# text-trans-full >RWm L> KRWXYN> RWXYNHWn D>WMJ> W<L DXVJNn W>RGJZNN QWMWJ >T<BDW B<LJDBBN> DJJNJn
# >RWm L> KRWXYN> RWXYNHWn D>WMJ> W<L DXVJNn W>RGJZNN QWMWJ >T<BDW B<LJDBBN> DJJNJn
#
# T.text default ארום עמא איליין חמתהון מדמיא לחמתהון דתניניא בזמן דהינון אשׁתן חמר ורוגזיהון מדמיא לרישׁי חיוין פתנניא אכזראי
# segment ארום עמא איליין חמתהון מדמיא לחמתהון דתניניא בזמן דהינון אשׁתן חמר ורוגזיהון מדמיא לרישׁי חיוין פתנניא אכזראי
# text-orig-full ארום עמא איליין חמתהון מדמיא לחמתהון דתניניא בזמן דהינון אשׁתן חמר ורוגזיהון מדמיא לרישׁי חיוין פתנניא אכזראי
# text-cons ארום עמא איליין חמתהון מדמיא לחמתהון דתניניא בזמן דהינון אשׁתן חמר ורוגזיהון מדמיא לרישׁי חיוין פתנניא אכזראי
# text-trans-full >RWm <M> >JLJJn XMTHWn MDMJ> LXMTHWn DTNJNJ> BZMn DHJNWn >CTn XMR WRWGZJHWn MDMJ> LRJCJ XJWJn PTNNJ> >KZR>J
# >RWm <M> >JLJJn XMTHWn MDMJ> LXMTHWn DTNJNJ> BZMn DHJNWn >CTn XMR WRWGZJHWn MDMJ> LRJCJ XJWJn PTNNJ> >KZR>J
#
# T.text default הלא הוא כסא דפורענותא ממזג ומתקן לרשׁיעיא באוצרי ליום דינא רבא
# segment הלא הוא כסא דפורענותא ממזג ומתקן לרשׁיעיא באוצרי ליום דינא רבא
# text-orig-full הלא הוא כסא דפורענותא ממזג ומתקן לרשׁיעיא באוצרי ליום דינא רבא
# text-cons הלא הוא כסא דפורענותא ממזג ומתקן לרשׁיעיא באוצרי ליום דינא רבא
# text-trans-full HL> HW> KS> DPWR<NWT> MMZG WMTQn LRCJ<J> B>WYRJ LJWm DJN> RB>
# HL> HW> KS> DPWR<NWT> MMZG WMTQn LRCJ<J> B>WYRJ LJWm DJN> RB>
#
# T.text default די היא נקמתא ואנא הוא דמשׁלם עידןל דתימות רגליהון דצדיקיא ארום קריב יום תבריהון דרשׁיעיא ואשׁ גיהנם עתידא להון ומייתי פורענותא עליהון
# segment דידי היא נקמתא ואנא הוא דמשׁלם לעידן דתימוט רגליהון דצדיקיא ארום קריב יום תבריהון דרשׁיעיא ואשׁ גיהנם עתידא להון ומייתי פורענותא עליהון
# text-orig-full די היא נקמתא ואנא הוא דמשׁלם עידןל דתימות רגליהון דצדיקיא ארום קריב יום תבריהון דרשׁיעיא ואשׁ גיהנם עתידא להון ומייתי פורענותא עליהון
# text-cons די היא נקמתא ואנא הוא דמשׁלם עידןל דתימות רגליהון דצדיקיא ארום קריב יום תבריהון דרשׁיעיא ואשׁ גיהנם עתידא להון ומייתי פורענותא עליהון
# text-trans-full DJ HJ> NQMT> W>N> HW> DMCLm <JDNL DTJMWT RGLJHWn DYDJQJ> >RWm QRJB JWm TBRJHWn DRCJ<J> W>C GJHNm <TJD> LHWn WMJJTJ PWR<NWT> <LJHWn
# DJ HJ> NQMT> W>N> HW> DMCLm <JDNL DTJMWT RGLJHWn DYDJQJ> >RWm QRJB JWm TBRJHWn DRCJ<J> W>C GJHNm <TJD> LHWn WMJJTJ PWR<NWT> <LJHWn
#
# T.text default עתידין הן אומיא למימר האן הוא אלההון דרוחצנהון ביה
# segment עתידין הן אומיא למימר האן הוא אלההון דרוחצנהון ביה
# text-orig-full עתידין הן אומיא למימר האן הוא אלההון דרוחצנהון ביה
# text-cons עתידין הן אומיא למימר האן הוא אלההון דרוחצנהון ביה
# text-trans-full <TJDJn Hn >WMJ> LMJMR H>n HW> >LHHWn DRWXYNHWN BJH
# <TJDJn Hn >WMJ> LMJMR H>n HW> >LHHWn DRWXYNHWN BJH
#
# T.text default ידי הון מקרבין קודשׁיא דתרביה נכסי קרבניהון וחמר ניסוכיהון הוו מקרבין קומוי יקום כען ויפרוק יתכון וגו
# segment ידי הון מקרבין קודשׁיא דתרביה נכסי קרבניהון וחמר ניסוכיהון הוו מקרבין קומוי יקום כען ויפרוק יתכון וגו
# text-orig-full ידי הון מקרבין קודשׁיא דתרביה נכסי קרבניהון וחמר ניסוכיהון הוו מקרבין קומוי יקום כען ויפרוק יתכון וגו
# text-cons ידי הון מקרבין קודשׁיא דתרביה נכסי קרבניהון וחמר ניסוכיהון הוו מקרבין קומוי יקום כען ויפרוק יתכון וגו
# text-trans-full JDJ HWn MQRBJn QWDCJ> DTRBJH NKSJ QRBNJHWn WXMR NJSWKJHWn HWW MQRBJn QWMWJ JQWm K<n WJPRWQ JTKWn WGW
# JDJ HWn MQRBJn QWDCJ> DTRBJH NKSJ QRBNJHWn WXMR NJSWKJHWn HWW MQRBJn QWMWJ JQWm K<n WJPRWQ JTKWn WGW
# text-trans-full W>MR JJJ MSJNJ >JTGLJ LMJTn >WRJT> L<MJH BNJ JCR>L DNX B>JQR <L VWR> DGBL> LMJTn >WRJT> LBNWJ D<CW WKJWn D>CKXW KTJB BGWWH L> THWWn QVWLJn L> QBJLW JTH HWPJ< B>JQR <L VWR> DP>Rn LMJTn >WRJT> LBNWJ DJCM<>L KJWn D>CKXW KTJB BGWWH L> THWWn GNBJn L> QBJLW JTH XZR W>JTGLJ <L VWR> DSJNJ W<JMJH RBWWn DML>KJn QDJCJn >MRJn BNJ JCR>L KL M> DMLJL MJMR> DJJJ N<BJD WNQBL PCV JMJNJH MnGW LHBJ >JCT> W>WRJT> JHB L<MJH
# W>MR JJJ MSJNJ >JTGLJ LMJTn >WRJT> L<MJH BNJ JCR>L DNX B>JQR <L VWR> DGBL> LMJTn >WRJT> LBNWJ D<CW WKJWn D>CKXW KTJB BGWWH L> THWWn QVWLJn L> QBJLW JTH HWPJ< B>JQR <L VWR> DP>Rn LMJTn >WRJT> LBNWJ DJCM<>L KJWn D>CKXW KTJB BGWWH L> THWWn GNBJn L> QBJLW JTH XZR W>JTGLJ <L VWR> DSJNJ W<JMJH RBWWn DML>KJn QDJCJn >MRJn BNJ JCR>L KL M> DMLJL MJMR> DJJJ N<BJD WNQBL PCV JMJNJH MnGW LHBJ >JCT> W>WRJT> JHB L<MJH
#
# T.text default הלא
# segment הלא גלוי וידוע דלאו בנוי דעשׁו וישׁמעאל מקבלין אוריתא אלא כדי למחבבא בני ישׁראל כוות ריבבן
# text-orig-full הלא
# text-cons הלא
# text-trans-full HL>
# HL>
#
# T.text default גלוי וידוע דלאו בן דעשׁו וישׁמעאל מקבלין אוריתא אלא כדי למחבבא בני ישׁראל ות ריבבן מלאכין קדישׁין אעגד דהוא מייתי עליהון ייסורין סגיעין לא נייחין ולא שׁדכין מאולפן אוריתא והא הינון מדברין ואתיין על רגל עננוי ושׁריין עלפםעל דברוי
# segment דאעג דהוא מייתי עליהון ייסורין סגיעין לא נייחין ולא שׁדכין מאולפן אוריתא והא הינון מדברין ואתיין על רגל עננוי ושׁריין על פם דברוי
# text-orig-full גלוי וידוע דלאו בן דעשׁו וישׁמעאל מקבלין אוריתא אלא כדי למחבבא בני ישׁראל ות ריבבן מלאכין קדישׁין אעגד דהוא מייתי עליהון ייסורין סגיעין לא נייחין ולא שׁדכין מאולפן אוריתא והא הינון מדברין ואתיין על רגל עננוי ושׁריין עלפםעל דברוי
# text-cons גלוי וידוע דלאו בן דעשׁו וישׁמעאל מקבלין אוריתא אלא כדי למחבבא בני ישׁראל ות ריבבן מלאכין קדישׁין אעגד דהוא מייתי עליהון ייסורין סגיעין לא נייחין ולא שׁדכין מאולפן אוריתא והא הינון מדברין ואתיין על רגל עננוי ושׁריין עלפםעל דברוי
# text-trans-full GLWJ WJDW< DL>W BN D<CW WJCM<>L MQBLJn >WRJT> >L> KDJ LMXBB> BNJ JCR>L WT RJBBn ML>KJn QDJCJn ><GD DHW> MJJTJ <LJHWn JJSWRJn SGJ<Jn L> NJJXJn WL> CDKJn M>WLPN >WRJT> WH> HJNWn MDBRJn W>TJJn <L RGL <NNWJ WCRJJn <LPm<L DBRWJ
# GLWJ WJDW< DL>W BN D<CW WJCM<>L MQBLJn >WRJT> >L> KDJ LMXBB> BNJ JCR>L WT RJBBn ML>KJn QDJCJn ><GD DHW> MJJTJ <LJHWn JJSWRJn SGJ<Jn L> NJJXJn WL> CDKJn M>WLPN >WRJT> WH> HJNWn MDBRJn W>TJJn <L RGL <NNWJ WCRJJn <LPm<L DBRWJ
#
# T.text default אמרין בני ישׁראל אוריתא פקיד יתן משׁה יהב יתה ירתא ואחסנא לכנשׁת יעקב
# segment אמרין בני ישׁראל אוריתא פקיד יתן משׁה יהב יתה ירתא ואחסנא לכנשׁת יעקב
# text-orig-full אמרין בני ישׁראל אוריתא פקיד יתן משׁה יהב יתה ירתא ואחסנא לכנשׁת יעקב
# text-cons אמרין בני ישׁראל אוריתא פקיד יתן משׁה יהב יתה ירתא ואחסנא לכנשׁת יעקב
# text-trans-full >MRJn BNJ JCR>L >WRJT> PQJD JTn MCH JHB JTH JRT> W>XSN> LKNCT J<QB
# >MRJn BNJ JCR>L >WRJT> PQJD JTn MCH JHB JTH JRT> W>XSN> LKNCT J<QB
#
# T.text default יחי ראובן בעלמא הדין ולא ימית במותא תניינא דבה מותה מייתין רשׁיעין לעלמא דאתי ויהוון עולימוי עם גיברין במנין
# segment יחי ראובן בעלמא הדין ולא ימית במותא תניינא דבה מותה מייתין רשׁיעין לעלמא דאתי ויהוון עולימוי עם גיברין במנין
# text-orig-full יחי ראובן בעלמא הדין ולא ימית במותא תניינא דבה מותה מייתין רשׁיעין לעלמא דאתי ויהוון עולימוי עם גיברין במנין
# text-cons יחי ראובן בעלמא הדין ולא ימית במותא תניינא דבה מותה מייתין רשׁיעין לעלמא דאתי ויהוון עולימוי עם גיברין במנין
# text-trans-full JXJ R>WBn B<LM> HDJn WL> JMJT BMWT> TNJJN> DBH MWTH MJJTJn RCJ<Jn L<LM> D>TJ WJHWWn <WLJMWJ <m GJBRJn BMNJN
# JXJ R>WBn B<LM> HDJn WL> JMJT BMWT> TNJJN> DBH MWTH MJJTJn RCJ<Jn L<LM> D>TJ WJHWWn <WLJMWJ <m GJBRJn BMNJN
#
# T.text default לאהרן חסידא
# segment לאהרן חסידא
# text-orig-full לאהרן חסידא
# text-cons לאהרן חסידא
# text-trans-full L>HRn XSJD>
# L>HRn XSJD>
#
# T.text default דאמיר על בני שׁיבטא דלוי לאבוי ואם לא נסב אפין בדינא וית אחוי לא חכם בעובדא דעיגלא
# segment דאמיר על בני שׁיבטא דלוי לאבוי ולאימיה לא נסב אפין בדינא וית אחוי לא חכם בעובדא דעיגלא
# text-orig-full דאמיר על בני שׁיבטא דלוי לאבוי ואם לא נסב אפין בדינא וית אחוי לא חכם בעובדא דעיגלא
# text-cons דאמיר על בני שׁיבטא דלוי לאבוי ואם לא נסב אפין בדינא וית אחוי לא חכם בעובדא דעיגלא
# text-trans-full D>MJR <L BNJ CJBV> DLWJ L>BWJ W>M L> NSB >PJn BDJN> WJT >XWJ L> XKm B<WBD> D<JGL>
# D>MJR <L BNJ CJBV> DLWJ L>BWJ W>M L> NSB >PJn BDJN> WJT >XWJ L> XKm B<WBD> D<JGL>
#
# T.text default עבדין פירין טבין בזכות תלתי אבהתא אברהם יצחק ויעקב דמתילין בתווריא ובזכות ארבעתי אמהתא דמתילן בגלימתא שׁרה ורבקה ורחל ולאה
# segment עבדין פירין טבין בזכות תלתי אבהתא אברהם יצחק ויעקב דמתילין בטווריא ובזכות ארבעתי אמהתא דמתילן בגלימתא שׁרה ורבקה ורחל ולאה
# text-orig-full עבדין פירין טבין בזכות תלתי אבהתא אברהם יצחק ויעקב דמתילין בתווריא ובזכות ארבעתי אמהתא דמתילן בגלימתא שׁרה ורבקה ורחל ולאה
# text-cons עבדין פירין טבין בזכות תלתי אבהתא אברהם יצחק ויעקב דמתילין בתווריא ובזכות ארבעתי אמהתא דמתילן בגלימתא שׁרה ורבקה ורחל ולאה
# text-trans-full <BDJn PJRJn VBJn BZKWT TLTJ >BHT> >BRHm JYXQ WJ<QB DMTJLJn BTWWRJ> WBZKWT >RB<TJ >MHT> DMTJLn BGLJMT> CRH WRBQH WRXL WL>H
# <BDJn PJRJn VBJn BZKWT TLTJ >BHT> >BRHm JYXQ WJ<QB DMTJLJn BTWWRJ> WBZKWT >RB<TJ >MHT> DMTJLn BGLJMT> CRH WRBQH WRXL WL>H
#
# T.text default דגברא דהוה שׁליט בארעא דמצרים וזהיר באיקרא דאחוי
# segment דגברא דהוה שׁליט בארעא דמצרים וזהיר באיקרא דאחוי
# text-orig-full דגברא דהוה שׁליט בארעא דמצרים וזהיר באיקרא דאחוי
# text-cons דגברא דהוה שׁליט בארעא דמצרים וזהיר באיקרא דאחוי
# text-trans-full DGBR> DHWH CLJV B>R<> DMYRJm WZHJR B>JQR> D>XWJ
# DGBR> DHWH CLJV B>R<> DMYRJm WZHJR B>JQR> D>XWJ
#
# T.text default בכירותא ומלכותא והדרא דיוסף הינון ארום כמא דלא איפשׁר
# segment בכירותא ומלכותא והדרא דיוסף הינון ארום כמא דלא איפשׁר
# text-orig-full בכירותא ומלכותא והדרא דיוסף הינון ארום כמא דלא איפשׁר
# text-cons בכירותא ומלכותא והדרא דיוסף הינון ארום כמא דלא איפשׁר
# text-trans-full BKJRWT> WMLKWT> WHDR> DJWSp HJNWn >RWm KM> DL> >JPCR
# BKJRWT> WMLKWT> WHDR> DJWSp HJNWn >RWm KM> DL> >JPCR
#
# T.text default ללמפלוח
# segment למפלוח
# text-orig-full ללמפלוח
# text-cons ללמפלוח
# text-trans-full LLMPLWX
# LLMPLWX
#
# T.text default בבכורי תוריא ולית למשׁתעבדא בקרני ראמא אלא היךמא דתורא וראמא נגחין בקרנתא כין יהוון עמא האיליין בני שׁיבטא דיוסף נפקין לקרבא לקבל שׁנאיהון ומקטלין בהון מלכין ושׁלתונין הינון רבוותא דקטל יהושׁע בר נון מן אמוראי דהוא מן שׁיבטא דבנוי דאפרים והינון אלפיא דקטל גדעון בר יואשׁ מן מדינאי דהוא משׁיבתא דמנשׁה
# segment בבכורי תוריא ולית למשׁתעבדא בקרני ראמא אלא היך מא דתורא וראמא נגחין בקרנתא כין יהוון עמא האיליין בני שׁיבטא דיוסף נפקין לקרבא לקבל שׁנאיהון ומקטלין בהון מלכין ושׁלטונין הינון רבוותא דקטל יהושׁע בר נון מן אמוראי דהוא מן שׁיבטא דבנוי דאפרים והינון אלפיא דקטל גדעון בר יואשׁ מן מדינאי דהוא משׁיבטא דמנשׁה
# text-orig-full בבכורי תוריא ולית למשׁתעבדא בקרני ראמא אלא היךמא דתורא וראמא נגחין בקרנתא כין יהוון עמא האיליין בני שׁיבטא דיוסף נפקין לקרבא לקבל שׁנאיהון ומקטלין בהון מלכין ושׁלתונין הינון רבוותא דקטל יהושׁע בר נון מן אמוראי דהוא מן שׁיבטא דבנוי דאפרים והינון אלפיא דקטל גדעון בר יואשׁ מן מדינאי דהוא משׁיבתא דמנשׁה
# text-cons בבכורי תוריא ולית למשׁתעבדא בקרני ראמא אלא היךמא דתורא וראמא נגחין בקרנתא כין יהוון עמא האיליין בני שׁיבטא דיוסף נפקין לקרבא לקבל שׁנאיהון ומקטלין בהון מלכין ושׁלתונין הינון רבוותא דקטל יהושׁע בר נון מן אמוראי דהוא מן שׁיבטא דבנוי דאפרים והינון אלפיא דקטל גדעון בר יואשׁ מן מדינאי דהוא משׁיבתא דמנשׁה
# text-trans-full BBKWRJ TWRJ> WLJT LMCT<BD> BQRNJ R>M> >L> HJkM> DTWR> WR>M> NGXJn BQRNT> KJn JHWWn <M> H>JLJJn BNJ CJBV> DJWSp NPQJn LQRB> LQBL CN>JHWn WMQVLJn BHWn MLKJn WCLTWNJN HJNWn RBWWT> DQVL JHWC< BR NWn Mn >MWR>J DHW> Mn CJBV> DBNWJ D>PRJm WHJNWn >LPJ> DQVL GD<Wn BR JW>C Mn MDJN>J DHW> MCJBT> DMNCH
# BBKWRJ TWRJ> WLJT LMCT<BD> BQRNJ R>M> >L> HJkM> DTWR> WR>M> NGXJn BQRNT> KJn JHWWn <M> H>JLJJn BNJ CJBV> DJWSp NPQJn LQRB> LQBL CN>JHWn WMQVLJn BHWn MLKJn WCLTWNJN HJNWn RBWWT> DQVL JHWC< BR NWn Mn >MWR>J DHW> Mn CJBV> DBNWJ D>PRJm WHJNWn >LPJ> DQVL GD<Wn BR JW>C Mn MDJN>J DHW> MCJBT> DMNCH
#
# T.text default ולזבולן אמר חדי זבולון במפקכון לפרגמטיכון וחדון בני ישׁשׁכר בבכון בביתמדרשׁיכון
# segment ולזבולן אמר חדי זבולון במפקכון לפרגמטיכון וחדון בני ישׁשׁכר במייתבכון בבית מדרשׁיכון
# text-orig-full ולזבולן אמר חדי זבולון במפקכון לפרגמטיכון וחדון בני ישׁשׁכר בבכון בביתמדרשׁיכון
# text-cons ולזבולן אמר חדי זבולון במפקכון לפרגמטיכון וחדון בני ישׁשׁכר בבכון בביתמדרשׁיכון
# text-trans-full WLZBWLN >MR XDJ ZBWLWn BMPQKWN LPRGMVJKWn WXDWn BNJ JCCKR BBKWn BBJTMDRCJKWN
# WLZBWLN >MR XDJ ZBWLWn BMPQKWN LPRGMVJKWn WXDWn BNJ JCCKR BBKWn BBJTMDRCJKWN
